# %%
# !pip install numpy rawpy tensorflow tf_slim
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (1.22.4)
# Collecting rawpy
#   Downloading rawpy-0.18.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 18.1 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.9/dist-packages (2.12.0)
# Requirement already satisfied: tf_slim in /usr/local/lib/python3.9/dist-packages (1.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.53.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (16.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from tensorflow) (67.6.1)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (23.3.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.9/dist-packages (from tensorflow) (23.1)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.4.8)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (0.32.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (2.12.2)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.9/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.9/dist-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.9/dist-packages (from jax>=0.3.15->tensorflow) (0.1.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.9/dist-packages (from jax>=0.3.15->tensorflow) (1.10.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.27.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.4.3)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.2.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.17.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.7.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.9/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.9/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.9/dist-packages (from markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow) (6.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (1.26.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.9/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.13,>=2.12->tensorflow) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.9/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)
# Installing collected packages: rawpy
# Successfully installed rawpy-0.18.0

# %%
# uniform content loss + adaptive threshold + per_class_input + recursive G
# improvement upon cqf37
from __future__ import division
import os, time, scipy.io
#import tensorflow as tf
#import tensorflow.contrib.slim as slim
import numpy as np
import rawpy
import glob
import random

#Hi i added this
import tf_slim as slim
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
from PIL import Image

start_time = time.strftime("%H:%M:%S", time.gmtime(time.time()))

# Google colab finding files:
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Note that you need a link to the shared folder in your google drive!
project_dir = '/content/drive/MyDrive/DLP/'
link_dir = project_dir + 'F1 pictures/'
run_name = 'F1_'

input_dir = link_dir + 'short/'
gt_dir = link_dir + 'long/'
checkpoint_dir = project_dir + run_name + 'models/'
result_dir = project_dir + run_name + 'results/'

# CHANGE THIS ACCORDING TO YOUR DEPTH
bit_depth = 10

# get train IDs
train_fns = glob.glob(gt_dir + '0*.dng')
train_ids = [int(os.path.basename(train_fn)[0:5]) for train_fn in train_fns]

ps = 512  # patch size for training
save_freq = 500

DEBUG = 0
if DEBUG == 1:
    save_freq = 2
    train_ids = train_ids[0:5]
    
_errstr = "Mode is unknown or incompatible with input array shape."

# https://stackoverflow.com/questions/57545125/attributeerror-module-scipy-misc-has-no-attribute-toimage
def bytescale(data, cmin=None, cmax=None, high=255, low=0):
    """
    Byte scales an array (image).
    Byte scaling means converting the input image to uint8 dtype and scaling
    the range to ``(low, high)`` (default 0-255).
    If the input image already has dtype uint8, no scaling is done.
    This function is only available if Python Imaging Library (PIL) is installed.
    Parameters
    ----------
    data : ndarray
        PIL image data array.
    cmin : scalar, optional
        Bias scaling of small values. Default is ``data.min()``.
    cmax : scalar, optional
        Bias scaling of large values. Default is ``data.max()``.
    high : scalar, optional
        Scale max value to `high`.  Default is 255.
    low : scalar, optional
        Scale min value to `low`.  Default is 0.
    Returns
    -------
    img_array : uint8 ndarray
        The byte-scaled array.
    Examples
    --------
    >>> from scipy.misc import bytescale
    >>> img = np.array([[ 91.06794177,   3.39058326,  84.4221549 ],
    ...                 [ 73.88003259,  80.91433048,   4.88878881],
    ...                 [ 51.53875334,  34.45808177,  27.5873488 ]])
    >>> bytescale(img)
    array([[255,   0, 236],
           [205, 225,   4],
           [140,  90,  70]], dtype=uint8)
    >>> bytescale(img, high=200, low=100)
    array([[200, 100, 192],
           [180, 188, 102],
           [155, 135, 128]], dtype=uint8)
    >>> bytescale(img, cmin=0, cmax=255)
    array([[91,  3, 84],
           [74, 81,  5],
           [52, 34, 28]], dtype=uint8)
    """
    if data.dtype == np.uint8:
        return data

    if high > 255:
        raise ValueError("`high` should be less than or equal to 255.")
    if low < 0:
        raise ValueError("`low` should be greater than or equal to 0.")
    if high < low:
        raise ValueError("`high` should be greater than or equal to `low`.")

    if cmin is None:
        cmin = data.min()
    if cmax is None:
        cmax = data.max()

    cscale = cmax - cmin
    if cscale < 0:
        raise ValueError("`cmax` should be larger than `cmin`.")
    elif cscale == 0:
        cscale = 1

    scale = float(high - low) / cscale
    bytedata = (data - cmin) * scale + low
    return (bytedata.clip(low, high) + 0.5).astype(np.uint8)


def toimage(arr, high=255, low=0, cmin=None, cmax=None, pal=None,
            mode=None, channel_axis=None):
    """Takes a numpy array and returns a PIL image.
    This function is only available if Python Imaging Library (PIL) is installed.
    The mode of the PIL image depends on the array shape and the `pal` and
    `mode` keywords.
    For 2-D arrays, if `pal` is a valid (N,3) byte-array giving the RGB values
    (from 0 to 255) then ``mode='P'``, otherwise ``mode='L'``, unless mode
    is given as 'F' or 'I' in which case a float and/or integer array is made.
    .. warning::
        This function uses `bytescale` under the hood to rescale images to use
        the full (0, 255) range if ``mode`` is one of ``None, 'L', 'P', 'l'``.
        It will also cast data for 2-D images to ``uint32`` for ``mode=None``
        (which is the default).
    Notes
    -----
    For 3-D arrays, the `channel_axis` argument tells which dimension of the
    array holds the channel data.
    For 3-D arrays if one of the dimensions is 3, the mode is 'RGB'
    by default or 'YCbCr' if selected.
    The numpy array must be either 2 dimensional or 3 dimensional.
    """
    data = np.asarray(arr)
    if np.iscomplexobj(data):
        raise ValueError("Cannot convert a complex-valued array.")
    shape = list(data.shape)
    valid = len(shape) == 2 or ((len(shape) == 3) and
                                ((3 in shape) or (4 in shape)))
    if not valid:
        raise ValueError("'arr' does not have a suitable array shape for "
                         "any mode.")
    if len(shape) == 2:
        shape = (shape[1], shape[0])  # columns show up first
        if mode == 'F':
            data32 = data.astype(np.float32)
            image = Image.frombytes(mode, shape, data32.tostring())
            return image
        if mode in [None, 'L', 'P']:
            bytedata = bytescale(data, high=high, low=low,
                                 cmin=cmin, cmax=cmax)
            image = Image.frombytes('L', shape, bytedata.tostring())
            if pal is not None:
                image.putpalette(np.asarray(pal, dtype=np.uint8).tostring())
                # Becomes a mode='P' automagically.
            elif mode == 'P':  # default gray-scale
                pal = (np.arange(0, 256, 1, dtype=np.uint8)[:, np.newaxis] *
                       np.ones((3,), dtype=np.uint8)[np.newaxis, :])
                image.putpalette(np.asarray(pal, dtype=np.uint8).tostring())
            return image
        if mode == '1':  # high input gives threshold for 1
            bytedata = (data > high)
            image = Image.frombytes('1', shape, bytedata.tostring())
            return image
        if cmin is None:
            cmin = np.amin(np.ravel(data))
        if cmax is None:
            cmax = np.amax(np.ravel(data))
        data = (data*1.0 - cmin)*(high - low)/(cmax - cmin) + low
        if mode == 'I':
            data32 = data.astype(np.uint32)
            image = Image.frombytes(mode, shape, data32.tostring())
        else:
            raise ValueError(_errstr)
        return image

    # if here then 3-d array with a 3 or a 4 in the shape length.
    # Check for 3 in datacube shape --- 'RGB' or 'YCbCr'
    if channel_axis is None:
        if (3 in shape):
            ca = np.flatnonzero(np.asarray(shape) == 3)[0]
        else:
            ca = np.flatnonzero(np.asarray(shape) == 4)
            if len(ca):
                ca = ca[0]
            else:
                raise ValueError("Could not find channel dimension.")
    else:
        ca = channel_axis

    numch = shape[ca]
    if numch not in [3, 4]:
        raise ValueError("Channel axis dimension is not valid.")

    bytedata = bytescale(data, high=high, low=low, cmin=cmin, cmax=cmax)
    if ca == 2:
        strdata = bytedata.tobytes()
        shape = (shape[1], shape[0])
    elif ca == 1:
        strdata = np.transpose(bytedata, (0, 2, 1)).tobytes()
        shape = (shape[2], shape[0])
    elif ca == 0:
        strdata = np.transpose(bytedata, (1, 2, 0)).tobytes()
        shape = (shape[2], shape[1])
    if mode is None:
        if numch == 3:
            mode = 'RGB'
        else:
            mode = 'RGBA'

    if mode not in ['RGB', 'RGBA', 'YCbCr', 'CMYK']:
        raise ValueError(_errstr)

    if mode in ['RGB', 'YCbCr']:
        if numch != 3:
            raise ValueError("Invalid array shape for mode.")
    if mode in ['RGBA', 'CMYK']:
        if numch != 4:
            raise ValueError("Invalid array shape for mode.")

    # Here we know data and mode is correct
    image = Image.frombytes(mode, shape, strdata)
    return image

def lrelu(x):
    return tf.maximum(x * 0.2, x)


def upsample_and_concat(x1, x2, output_channels, in_channels):
    pool_size = 2
    deconv_filter = tf.Variable(tf.truncated_normal([pool_size, pool_size, output_channels, in_channels], stddev=0.02))
    deconv = tf.nn.conv2d_transpose(x1, deconv_filter, tf.shape(x2), strides=[1, pool_size, pool_size, 1])

    deconv_output = tf.concat([deconv, x2], 3)
    deconv_output.set_shape([None, None, None, output_channels * 2])

    return deconv_output


def network(input):
    conv1 = slim.conv2d(input, 32, [3, 3], rate=1, activation_fn=lrelu, scope='g_conv1_1')
    conv1 = slim.conv2d(conv1, 32, [3, 3], rate=1, activation_fn=lrelu, scope='g_conv1_2')
    pool1 = slim.max_pool2d(conv1, [2, 2], padding='SAME')

    conv2 = slim.conv2d(pool1, 64, [3, 3], rate=1, activation_fn=lrelu, scope='g_conv2_1')
    conv2 = slim.conv2d(conv2, 64, [3, 3], rate=1, activation_fn=lrelu, scope='g_conv2_2')
    pool2 = slim.max_pool2d(conv2, [2, 2], padding='SAME')

    conv3 = slim.conv2d(pool2, 128, [3, 3], rate=1, activation_fn=lrelu, scope='g_conv3_1')
    conv3 = slim.conv2d(conv3, 128, [3, 3], rate=1, activation_fn=lrelu, scope='g_conv3_2')
    pool3 = slim.max_pool2d(conv3, [2, 2], padding='SAME')

    conv4 = slim.conv2d(pool3, 256, [3, 3], rate=1, activation_fn=lrelu, scope='g_conv4_1')
    conv4 = slim.conv2d(conv4, 256, [3, 3], rate=1, activation_fn=lrelu, scope='g_conv4_2')
    pool4 = slim.max_pool2d(conv4, [2, 2], padding='SAME')

    conv5 = slim.conv2d(pool4, 512, [3, 3], rate=1, activation_fn=lrelu, scope='g_conv5_1')
    conv5 = slim.conv2d(conv5, 512, [3, 3], rate=1, activation_fn=lrelu, scope='g_conv5_2')

    up6 = upsample_and_concat(conv5, conv4, 256, 512)
    conv6 = slim.conv2d(up6, 256, [3, 3], rate=1, activation_fn=lrelu, scope='g_conv6_1')
    conv6 = slim.conv2d(conv6, 256, [3, 3], rate=1, activation_fn=lrelu, scope='g_conv6_2')

    up7 = upsample_and_concat(conv6, conv3, 128, 256)
    conv7 = slim.conv2d(up7, 128, [3, 3], rate=1, activation_fn=lrelu, scope='g_conv7_1')
    conv7 = slim.conv2d(conv7, 128, [3, 3], rate=1, activation_fn=lrelu, scope='g_conv7_2')

    up8 = upsample_and_concat(conv7, conv2, 64, 128)
    conv8 = slim.conv2d(up8, 64, [3, 3], rate=1, activation_fn=lrelu, scope='g_conv8_1')
    conv8 = slim.conv2d(conv8, 64, [3, 3], rate=1, activation_fn=lrelu, scope='g_conv8_2')

    up9 = upsample_and_concat(conv8, conv1, 32, 64)
    conv9 = slim.conv2d(up9, 32, [3, 3], rate=1, activation_fn=lrelu, scope='g_conv9_1')
    conv9 = slim.conv2d(conv9, 32, [3, 3], rate=1, activation_fn=lrelu, scope='g_conv9_2')

    conv10 = slim.conv2d(conv9, 12, [1, 1], rate=1, activation_fn=None, scope='g_conv10')
    out = tf.depth_to_space(conv10, 2)
    return out


def pack_raw(raw):
    # pack Bayer image to 4 channels
    im = raw.raw_image_visible.astype(np.float32)

    im = np.expand_dims(im, axis=2)
    im = im[:2800,:4000,:]
    img_shape = im.shape

    H = 2800
    W = 4000

    out = np.concatenate((im[0:H:2, 0:W:2, :],
                          im[0:H:2, 1:W:2, :],
                          im[1:H:2, 1:W:2, :],
                          im[1:H:2, 0:W:2, :]), axis=2)
    
    black_levels = raw.black_level_per_channel

    for i, bl in enumerate(black_levels):
      out[:,:,i] = np.maximum(out[:,:,i] - bl, 0) / (float(pow(2, bit_depth) - 1) - bl)  # subtract the black level
      
    return out

# Added this for rerun
tf.reset_default_graph()

sess = tf.Session()
in_image = tf.placeholder(tf.float32, [None, None, None, 4])
gt_image = tf.placeholder(tf.float32, [None, None, None, 3])
out_image = network(in_image)

G_loss = tf.reduce_mean(tf.abs(out_image - gt_image))

t_vars = tf.trainable_variables()
lr = tf.placeholder(tf.float32)
G_opt = tf.train.AdamOptimizer(learning_rate=lr).minimize(G_loss)

saver = tf.train.Saver()
sess.run(tf.global_variables_initializer())
ckpt = tf.train.get_checkpoint_state(checkpoint_dir)
if ckpt:
    print('loaded ' + ckpt.model_checkpoint_path)
    saver.restore(sess, ckpt.model_checkpoint_path)

# Raw data takes long time to load. Keep them in memory after loaded.
gt_images = [None] * 6000
input_images = {}
input_images['300'] = [None] * len(train_ids)
input_images['250'] = [None] * len(train_ids)
input_images['100'] = [None] * len(train_ids)

g_loss = np.zeros((5000, 1))

allfolders = glob.glob(result_dir + '*0')
lastepoch = 0
for folder in allfolders:
    lastepoch = np.maximum(lastepoch, int(folder[-4:]))

learning_rate = 1e-4
for epoch in range(lastepoch, 4001):
    if os.path.isdir(result_dir + '%04d' % epoch):
        continue
    cnt = 0
    if epoch > 2000:
        learning_rate = 1e-5

    for ind in np.random.permutation(len(train_ids)):
        # get the path from image id
        train_id = train_ids[ind]
        in_files = glob.glob(input_dir + '%05d_00*.dng' % train_id)
        in_path = in_files[np.random.randint(0, len(in_files) - 1)]
        in_fn = os.path.basename(in_path)

        gt_files = glob.glob(gt_dir + '%05d_00*.dng' % train_id)
        gt_path = gt_files[0]
        gt_fn = os.path.basename(gt_path)

        in_exposure = float(in_fn.split('_')[-1].split('s')[0])
        gt_exposure = float(gt_fn.split('_')[-1].split('s')[0])

        ratio = min(gt_exposure / in_exposure, 300)
        index = str(ratio)

        if index not in input_images:
          input_images[index] = [None] * len(train_ids)

        st = time.time()
        cnt += 1

        if input_images[index][ind] is None:

            raw = rawpy.imread(in_path)
            input_images[index][ind] = np.expand_dims(pack_raw(raw), axis=0) * ratio
            gt_raw = rawpy.imread(gt_path)
            im = gt_raw.postprocess(use_camera_wb=True, half_size=False, no_auto_bright=True, output_bps=16)
            gt_images[ind] = np.expand_dims(np.float32(im / float(pow(2, 16) - 1)), axis=0)

        # crop
        H = input_images[index][ind].shape[1]
        W = input_images[index][ind].shape[2]

        xx = np.random.randint(0, W - ps)
        yy = np.random.randint(0, H - ps)
        input_patch = input_images[index][ind][:, yy:yy + ps, xx:xx + ps, :]
        gt_patch = gt_images[ind][:, yy * 2:yy * 2 + ps * 2, xx * 2:xx * 2 + ps * 2, :]

        if np.random.randint(2, size=1)[0] == 1:  # random flip
            input_patch = np.flip(input_patch, axis=1)
            gt_patch = np.flip(gt_patch, axis=1)
        if np.random.randint(2, size=1)[0] == 1:
            input_patch = np.flip(input_patch, axis=2)
            gt_patch = np.flip(gt_patch, axis=2)
        if np.random.randint(2, size=1)[0] == 1:  # random transpose
            input_patch = np.transpose(input_patch, (0, 2, 1, 3))
            gt_patch = np.transpose(gt_patch, (0, 2, 1, 3))

        input_patch = np.minimum(input_patch, 1.0)

        _, G_current, output = sess.run([G_opt, G_loss, out_image],
                                        feed_dict={in_image: input_patch, gt_image: gt_patch, lr: learning_rate})
        output = np.minimum(np.maximum(output, 0), 1)
        g_loss[ind] = G_current
        
        current_time = time.strftime("%H:%M:%S", time.gmtime(time.time()))
        print(f"File started at {start_time}, now at {current_time}.")
        print("%d %d Loss=%.3f Time=%.3f" % (epoch, cnt, np.mean(g_loss[np.where(g_loss)]), time.time() - st))

        if epoch % save_freq == 0:
            if not os.path.isdir(result_dir + '%04d' % epoch):
                os.makedirs(result_dir + '%04d' % epoch)

            temp = np.concatenate((gt_patch[0, :, :, :], output[0, :, :, :]), axis=1)
            toimage(temp * 255, high=255, low=0, cmin=0, cmax=255).save(
                result_dir + '%04d/%05d_00_train_%d.jpg' % (epoch, train_id, ratio))

    saver.save(sess, checkpoint_dir + 'model.ckpt')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.9/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Mounted at /content/drive
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/keras/engine/base_layer_v1.py:1694: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# Streaming output truncated to the last 5000 lines.
# File started at 14:49:30, now at 16:49:34.
# 3751 1 Loss=0.031 Time=0.141
# File started at 14:49:30, now at 16:49:34.
# 3751 2 Loss=0.033 Time=0.115
# File started at 14:49:30, now at 16:49:34.
# 3751 3 Loss=0.033 Time=0.145
# File started at 14:49:30, now at 16:49:34.
# 3751 4 Loss=0.033 Time=0.117
# File started at 14:49:30, now at 16:49:34.
# 3751 5 Loss=0.033 Time=0.176
# File started at 14:49:30, now at 16:49:34.
# 3751 6 Loss=0.033 Time=0.115
# File started at 14:49:30, now at 16:49:35.
# 3751 7 Loss=0.031 Time=0.180
# File started at 14:49:30, now at 16:49:35.
# 3751 8 Loss=0.031 Time=0.175
# File started at 14:49:30, now at 16:49:35.
# 3751 9 Loss=0.029 Time=0.187
# File started at 14:49:30, now at 16:49:35.
# 3751 10 Loss=0.030 Time=0.115
# File started at 14:49:30, now at 16:49:36.
# 3752 1 Loss=0.030 Time=0.168
# File started at 14:49:30, now at 16:49:36.
# 3752 2 Loss=0.029 Time=0.178
# File started at 14:49:30, now at 16:49:36.
# 3752 3 Loss=0.029 Time=0.118
# File started at 14:49:30, now at 16:49:37.
# 3752 4 Loss=0.031 Time=0.178
# File started at 14:49:30, now at 16:49:37.
# 3752 5 Loss=0.033 Time=0.129
# File started at 14:49:30, now at 16:49:37.
# 3752 6 Loss=0.034 Time=0.169
# File started at 14:49:30, now at 16:49:37.
# 3752 7 Loss=0.033 Time=0.177
# File started at 14:49:30, now at 16:49:37.
# 3752 8 Loss=0.033 Time=0.190
# File started at 14:49:30, now at 16:49:37.
# 3752 9 Loss=0.033 Time=0.159
# File started at 14:49:30, now at 16:49:37.
# 3752 10 Loss=0.034 Time=0.120
# File started at 14:49:30, now at 16:49:38.
# 3753 1 Loss=0.034 Time=0.107
# File started at 14:49:30, now at 16:49:38.
# 3753 2 Loss=0.033 Time=0.116
# File started at 14:49:30, now at 16:49:38.
# 3753 3 Loss=0.032 Time=0.147
# File started at 14:49:30, now at 16:49:39.
# 3753 4 Loss=0.032 Time=0.108
# File started at 14:49:30, now at 16:49:39.
# 3753 5 Loss=0.032 Time=0.140
# File started at 14:49:30, now at 16:49:39.
# 3753 6 Loss=0.032 Time=0.140
# File started at 14:49:30, now at 16:49:39.
# 3753 7 Loss=0.032 Time=0.145
# File started at 14:49:30, now at 16:49:39.
# 3753 8 Loss=0.032 Time=0.116
# File started at 14:49:30, now at 16:49:39.
# 3753 9 Loss=0.032 Time=0.111
# File started at 14:49:30, now at 16:49:39.
# 3753 10 Loss=0.032 Time=0.117
# File started at 14:49:30, now at 16:49:40.
# 3754 1 Loss=0.032 Time=0.139
# File started at 14:49:30, now at 16:49:40.
# 3754 2 Loss=0.032 Time=0.110
# File started at 14:49:30, now at 16:49:40.
# 3754 3 Loss=0.032 Time=0.141
# File started at 14:49:30, now at 16:49:40.
# 3754 4 Loss=0.032 Time=0.146
# File started at 14:49:30, now at 16:49:41.
# 3754 5 Loss=0.032 Time=0.137
# File started at 14:49:30, now at 16:49:41.
# 3754 6 Loss=0.031 Time=0.138
# File started at 14:49:30, now at 16:49:41.
# 3754 7 Loss=0.033 Time=0.144
# File started at 14:49:30, now at 16:49:41.
# 3754 8 Loss=0.034 Time=0.150
# File started at 14:49:30, now at 16:49:41.
# 3754 9 Loss=0.031 Time=0.143
# File started at 14:49:30, now at 16:49:41.
# 3754 10 Loss=0.031 Time=0.139
# File started at 14:49:30, now at 16:49:42.
# 3755 1 Loss=0.032 Time=0.138
# File started at 14:49:30, now at 16:49:42.
# 3755 2 Loss=0.029 Time=0.110
# File started at 14:49:30, now at 16:49:42.
# 3755 3 Loss=0.030 Time=0.116
# File started at 14:49:30, now at 16:49:42.
# 3755 4 Loss=0.029 Time=0.147
# File started at 14:49:30, now at 16:49:43.
# 3755 5 Loss=0.029 Time=0.143
# File started at 14:49:30, now at 16:49:43.
# 3755 6 Loss=0.028 Time=0.109
# File started at 14:49:30, now at 16:49:43.
# 3755 7 Loss=0.028 Time=0.110
# File started at 14:49:30, now at 16:49:43.
# 3755 8 Loss=0.028 Time=0.109
# File started at 14:49:30, now at 16:49:43.
# 3755 9 Loss=0.027 Time=0.148
# File started at 14:49:30, now at 16:49:43.
# 3755 10 Loss=0.028 Time=0.109
# File started at 14:49:30, now at 16:49:44.
# 3756 1 Loss=0.028 Time=0.109
# File started at 14:49:30, now at 16:49:44.
# 3756 2 Loss=0.028 Time=0.111
# File started at 14:49:30, now at 16:49:44.
# 3756 3 Loss=0.027 Time=0.109
# File started at 14:49:30, now at 16:49:44.
# 3756 4 Loss=0.028 Time=0.145
# File started at 14:49:30, now at 16:49:44.
# 3756 5 Loss=0.028 Time=0.148
# File started at 14:49:30, now at 16:49:45.
# 3756 6 Loss=0.028 Time=0.109
# File started at 14:49:30, now at 16:49:45.
# 3756 7 Loss=0.029 Time=0.146
# File started at 14:49:30, now at 16:49:45.
# 3756 8 Loss=0.028 Time=0.142
# File started at 14:49:30, now at 16:49:45.
# 3756 9 Loss=0.028 Time=0.140
# File started at 14:49:30, now at 16:49:45.
# 3756 10 Loss=0.029 Time=0.117
# File started at 14:49:30, now at 16:49:46.
# 3757 1 Loss=0.031 Time=0.117
# File started at 14:49:30, now at 16:49:46.
# 3757 2 Loss=0.031 Time=0.117
# File started at 14:49:30, now at 16:49:46.
# 3757 3 Loss=0.032 Time=0.142
# File started at 14:49:30, now at 16:49:46.
# 3757 4 Loss=0.032 Time=0.117
# File started at 14:49:30, now at 16:49:46.
# 3757 5 Loss=0.032 Time=0.109
# File started at 14:49:30, now at 16:49:46.
# 3757 6 Loss=0.033 Time=0.142
# File started at 14:49:30, now at 16:49:47.
# 3757 7 Loss=0.033 Time=0.110
# File started at 14:49:30, now at 16:49:47.
# 3757 8 Loss=0.032 Time=0.109
# File started at 14:49:30, now at 16:49:47.
# 3757 9 Loss=0.032 Time=0.109
# File started at 14:49:30, now at 16:49:47.
# 3757 10 Loss=0.032 Time=0.141
# File started at 14:49:30, now at 16:49:48.
# 3758 1 Loss=0.033 Time=0.178
# File started at 14:49:30, now at 16:49:48.
# 3758 2 Loss=0.033 Time=0.176
# File started at 14:49:30, now at 16:49:48.
# 3758 3 Loss=0.032 Time=0.116
# File started at 14:49:30, now at 16:49:48.
# 3758 4 Loss=0.032 Time=0.115
# File started at 14:49:30, now at 16:49:48.
# 3758 5 Loss=0.032 Time=0.117
# File started at 14:49:30, now at 16:49:48.
# 3758 6 Loss=0.033 Time=0.129
# File started at 14:49:30, now at 16:49:49.
# 3758 7 Loss=0.033 Time=0.177
# File started at 14:49:30, now at 16:49:49.
# 3758 8 Loss=0.033 Time=0.116
# File started at 14:49:30, now at 16:49:49.
# 3758 9 Loss=0.032 Time=0.173
# File started at 14:49:30, now at 16:49:49.
# 3758 10 Loss=0.032 Time=0.118
# File started at 14:49:30, now at 16:49:50.
# 3759 1 Loss=0.032 Time=0.131
# File started at 14:49:30, now at 16:49:50.
# 3759 2 Loss=0.032 Time=0.174
# File started at 14:49:30, now at 16:49:51.
# 3759 3 Loss=0.034 Time=0.116
# File started at 14:49:30, now at 16:49:51.
# 3759 4 Loss=0.034 Time=0.119
# File started at 14:49:30, now at 16:49:51.
# 3759 5 Loss=0.034 Time=0.172
# File started at 14:49:30, now at 16:49:51.
# 3759 6 Loss=0.034 Time=0.110
# File started at 14:49:30, now at 16:49:51.
# 3759 7 Loss=0.034 Time=0.137
# File started at 14:49:30, now at 16:49:51.
# 3759 8 Loss=0.034 Time=0.148
# File started at 14:49:30, now at 16:49:51.
# 3759 9 Loss=0.034 Time=0.117
# File started at 14:49:30, now at 16:49:51.
# 3759 10 Loss=0.033 Time=0.138
# File started at 14:49:30, now at 16:49:52.
# 3760 1 Loss=0.033 Time=0.109
# File started at 14:49:30, now at 16:49:52.
# 3760 2 Loss=0.034 Time=0.151
# File started at 14:49:30, now at 16:49:52.
# 3760 3 Loss=0.034 Time=0.116
# File started at 14:49:30, now at 16:49:53.
# 3760 4 Loss=0.034 Time=0.143
# File started at 14:49:30, now at 16:49:53.
# 3760 5 Loss=0.034 Time=0.116
# File started at 14:49:30, now at 16:49:53.
# 3760 6 Loss=0.034 Time=0.143
# File started at 14:49:30, now at 16:49:53.
# 3760 7 Loss=0.034 Time=0.117
# File started at 14:49:30, now at 16:49:53.
# 3760 8 Loss=0.034 Time=0.116
# File started at 14:49:30, now at 16:49:53.
# 3760 9 Loss=0.034 Time=0.142
# File started at 14:49:30, now at 16:49:53.
# 3760 10 Loss=0.035 Time=0.143
# File started at 14:49:30, now at 16:49:54.
# 3761 1 Loss=0.034 Time=0.111
# File started at 14:49:30, now at 16:49:54.
# 3761 2 Loss=0.035 Time=0.149
# File started at 14:49:30, now at 16:49:54.
# 3761 3 Loss=0.035 Time=0.139
# File started at 14:49:30, now at 16:49:55.
# 3761 4 Loss=0.035 Time=0.141
# File started at 14:49:30, now at 16:49:55.
# 3761 5 Loss=0.035 Time=0.115
# File started at 14:49:30, now at 16:49:55.
# 3761 6 Loss=0.035 Time=0.142
# File started at 14:49:30, now at 16:49:55.
# 3761 7 Loss=0.035 Time=0.142
# File started at 14:49:30, now at 16:49:55.
# 3761 8 Loss=0.035 Time=0.147
# File started at 14:49:30, now at 16:49:55.
# 3761 9 Loss=0.038 Time=0.145
# File started at 14:49:30, now at 16:49:55.
# 3761 10 Loss=0.038 Time=0.114
# File started at 14:49:30, now at 16:49:56.
# 3762 1 Loss=0.037 Time=0.108
# File started at 14:49:30, now at 16:49:56.
# 3762 2 Loss=0.038 Time=0.140
# File started at 14:49:30, now at 16:49:56.
# 3762 3 Loss=0.038 Time=0.141
# File started at 14:49:30, now at 16:49:56.
# 3762 4 Loss=0.038 Time=0.144
# File started at 14:49:30, now at 16:49:57.
# 3762 5 Loss=0.038 Time=0.119
# File started at 14:49:30, now at 16:49:57.
# 3762 6 Loss=0.038 Time=0.143
# File started at 14:49:30, now at 16:49:57.
# 3762 7 Loss=0.034 Time=0.145
# File started at 14:49:30, now at 16:49:57.
# 3762 8 Loss=0.034 Time=0.141
# File started at 14:49:30, now at 16:49:57.
# 3762 9 Loss=0.033 Time=0.118
# File started at 14:49:30, now at 16:49:57.
# 3762 10 Loss=0.034 Time=0.145
# File started at 14:49:30, now at 16:49:58.
# 3763 1 Loss=0.035 Time=0.116
# File started at 14:49:30, now at 16:49:58.
# 3763 2 Loss=0.034 Time=0.111
# File started at 14:49:30, now at 16:49:58.
# 3763 3 Loss=0.035 Time=0.114
# File started at 14:49:30, now at 16:49:58.
# 3763 4 Loss=0.033 Time=0.118
# File started at 14:49:30, now at 16:49:58.
# 3763 5 Loss=0.034 Time=0.121
# File started at 14:49:30, now at 16:49:59.
# 3763 6 Loss=0.033 Time=0.147
# File started at 14:49:30, now at 16:49:59.
# 3763 7 Loss=0.033 Time=0.146
# File started at 14:49:30, now at 16:49:59.
# 3763 8 Loss=0.033 Time=0.117
# File started at 14:49:30, now at 16:49:59.
# 3763 9 Loss=0.033 Time=0.148
# File started at 14:49:30, now at 16:49:59.
# 3763 10 Loss=0.031 Time=0.146
# File started at 14:49:30, now at 16:50:00.
# 3764 1 Loss=0.032 Time=0.118
# File started at 14:49:30, now at 16:50:00.
# 3764 2 Loss=0.031 Time=0.140
# File started at 14:49:30, now at 16:50:00.
# 3764 3 Loss=0.033 Time=0.115
# File started at 14:49:30, now at 16:50:00.
# 3764 4 Loss=0.033 Time=0.115
# File started at 14:49:30, now at 16:50:00.
# 3764 5 Loss=0.033 Time=0.115
# File started at 14:49:30, now at 16:50:01.
# 3764 6 Loss=0.032 Time=0.141
# File started at 14:49:30, now at 16:50:01.
# 3764 7 Loss=0.032 Time=0.116
# File started at 14:49:30, now at 16:50:01.
# 3764 8 Loss=0.032 Time=0.110
# File started at 14:49:30, now at 16:50:01.
# 3764 9 Loss=0.034 Time=0.129
# File started at 14:49:30, now at 16:50:01.
# 3764 10 Loss=0.034 Time=0.128
# File started at 14:49:30, now at 16:50:02.
# 3765 1 Loss=0.034 Time=0.169
# File started at 14:49:30, now at 16:50:02.
# 3765 2 Loss=0.031 Time=0.171
# File started at 14:49:30, now at 16:50:02.
# 3765 3 Loss=0.030 Time=0.117
# File started at 14:49:30, now at 16:50:02.
# 3765 4 Loss=0.030 Time=0.117
# File started at 14:49:30, now at 16:50:03.
# 3765 5 Loss=0.030 Time=0.129
# File started at 14:49:30, now at 16:50:03.
# 3765 6 Loss=0.030 Time=0.172
# File started at 14:49:30, now at 16:50:03.
# 3765 7 Loss=0.030 Time=0.134
# File started at 14:49:30, now at 16:50:03.
# 3765 8 Loss=0.030 Time=0.177
# File started at 14:49:30, now at 16:50:03.
# 3765 9 Loss=0.030 Time=0.132
# File started at 14:49:30, now at 16:50:03.
# 3765 10 Loss=0.029 Time=0.134
# File started at 14:49:30, now at 16:50:04.
# 3766 1 Loss=0.027 Time=0.157
# File started at 14:49:30, now at 16:50:04.
# 3766 2 Loss=0.028 Time=0.139
# File started at 14:49:30, now at 16:50:05.
# 3766 3 Loss=0.028 Time=0.117
# File started at 14:49:30, now at 16:50:05.
# 3766 4 Loss=0.028 Time=0.108
# File started at 14:49:30, now at 16:50:05.
# 3766 5 Loss=0.028 Time=0.111
# File started at 14:49:30, now at 16:50:05.
# 3766 6 Loss=0.031 Time=0.116
# File started at 14:49:30, now at 16:50:05.
# 3766 7 Loss=0.030 Time=0.144
# File started at 14:49:30, now at 16:50:05.
# 3766 8 Loss=0.030 Time=0.142
# File started at 14:49:30, now at 16:50:05.
# 3766 9 Loss=0.030 Time=0.143
# File started at 14:49:30, now at 16:50:06.
# 3766 10 Loss=0.030 Time=0.143
# File started at 14:49:30, now at 16:50:06.
# 3767 1 Loss=0.029 Time=0.109
# File started at 14:49:30, now at 16:50:06.
# 3767 2 Loss=0.028 Time=0.110
# File started at 14:49:30, now at 16:50:06.
# 3767 3 Loss=0.028 Time=0.141
# File started at 14:49:30, now at 16:50:07.
# 3767 4 Loss=0.027 Time=0.145
# File started at 14:49:30, now at 16:50:07.
# 3767 5 Loss=0.028 Time=0.113
# File started at 14:49:30, now at 16:50:07.
# 3767 6 Loss=0.028 Time=0.123
# File started at 14:49:30, now at 16:50:07.
# 3767 7 Loss=0.028 Time=0.116
# File started at 14:49:30, now at 16:50:07.
# 3767 8 Loss=0.029 Time=0.140
# File started at 14:49:30, now at 16:50:07.
# 3767 9 Loss=0.030 Time=0.140
# File started at 14:49:30, now at 16:50:07.
# 3767 10 Loss=0.030 Time=0.115
# File started at 14:49:30, now at 16:50:08.
# 3768 1 Loss=0.030 Time=0.108
# File started at 14:49:30, now at 16:50:08.
# 3768 2 Loss=0.030 Time=0.138
# File started at 14:49:30, now at 16:50:08.
# 3768 3 Loss=0.029 Time=0.115
# File started at 14:49:30, now at 16:50:08.
# 3768 4 Loss=0.030 Time=0.120
# File started at 14:49:30, now at 16:50:09.
# 3768 5 Loss=0.027 Time=0.117
# File started at 14:49:30, now at 16:50:09.
# 3768 6 Loss=0.027 Time=0.113
# File started at 14:49:30, now at 16:50:09.
# 3768 7 Loss=0.027 Time=0.139
# File started at 14:49:30, now at 16:50:09.
# 3768 8 Loss=0.029 Time=0.144
# File started at 14:49:30, now at 16:50:09.
# 3768 9 Loss=0.029 Time=0.150
# File started at 14:49:30, now at 16:50:09.
# 3768 10 Loss=0.030 Time=0.145
# File started at 14:49:30, now at 16:50:10.
# 3769 1 Loss=0.030 Time=0.107
# File started at 14:49:30, now at 16:50:10.
# 3769 2 Loss=0.032 Time=0.111
# File started at 14:49:30, now at 16:50:10.
# 3769 3 Loss=0.033 Time=0.118
# File started at 14:49:30, now at 16:50:10.
# 3769 4 Loss=0.032 Time=0.139
# File started at 14:49:30, now at 16:50:10.
# 3769 5 Loss=0.032 Time=0.111
# File started at 14:49:30, now at 16:50:11.
# 3769 6 Loss=0.032 Time=0.110
# File started at 14:49:30, now at 16:50:11.
# 3769 7 Loss=0.032 Time=0.112
# File started at 14:49:30, now at 16:50:11.
# 3769 8 Loss=0.032 Time=0.118
# File started at 14:49:30, now at 16:50:11.
# 3769 9 Loss=0.032 Time=0.116
# File started at 14:49:30, now at 16:50:11.
# 3769 10 Loss=0.032 Time=0.110
# File started at 14:49:30, now at 16:50:12.
# 3770 1 Loss=0.033 Time=0.116
# File started at 14:49:30, now at 16:50:12.
# 3770 2 Loss=0.032 Time=0.144
# File started at 14:49:30, now at 16:50:12.
# 3770 3 Loss=0.032 Time=0.118
# File started at 14:49:30, now at 16:50:12.
# 3770 4 Loss=0.031 Time=0.116
# File started at 14:49:30, now at 16:50:12.
# 3770 5 Loss=0.031 Time=0.142
# File started at 14:49:30, now at 16:50:12.
# 3770 6 Loss=0.031 Time=0.150
# File started at 14:49:30, now at 16:50:13.
# 3770 7 Loss=0.031 Time=0.140
# File started at 14:49:30, now at 16:50:13.
# 3770 8 Loss=0.031 Time=0.116
# File started at 14:49:30, now at 16:50:13.
# 3770 9 Loss=0.030 Time=0.109
# File started at 14:49:30, now at 16:50:13.
# 3770 10 Loss=0.031 Time=0.110
# File started at 14:49:30, now at 16:50:14.
# 3771 1 Loss=0.031 Time=0.145
# File started at 14:49:30, now at 16:50:14.
# 3771 2 Loss=0.030 Time=0.109
# File started at 14:49:30, now at 16:50:14.
# 3771 3 Loss=0.030 Time=0.143
# File started at 14:49:30, now at 16:50:14.
# 3771 4 Loss=0.030 Time=0.112
# File started at 14:49:30, now at 16:50:14.
# 3771 5 Loss=0.032 Time=0.113
# File started at 14:49:30, now at 16:50:14.
# 3771 6 Loss=0.032 Time=0.149
# File started at 14:49:30, now at 16:50:14.
# 3771 7 Loss=0.033 Time=0.125
# File started at 14:49:30, now at 16:50:15.
# 3771 8 Loss=0.033 Time=0.168
# File started at 14:49:30, now at 16:50:15.
# 3771 9 Loss=0.034 Time=0.128
# File started at 14:49:30, now at 16:50:15.
# 3771 10 Loss=0.033 Time=0.115
# File started at 14:49:30, now at 16:50:16.
# 3772 1 Loss=0.032 Time=0.129
# File started at 14:49:30, now at 16:50:16.
# 3772 2 Loss=0.032 Time=0.129
# File started at 14:49:30, now at 16:50:16.
# 3772 3 Loss=0.031 Time=0.127
# File started at 14:49:30, now at 16:50:16.
# 3772 4 Loss=0.031 Time=0.177
# File started at 14:49:30, now at 16:50:16.
# 3772 5 Loss=0.029 Time=0.186
# File started at 14:49:30, now at 16:50:17.
# 3772 6 Loss=0.029 Time=0.128
# File started at 14:49:30, now at 16:50:17.
# 3772 7 Loss=0.029 Time=0.174
# File started at 14:49:30, now at 16:50:17.
# 3772 8 Loss=0.028 Time=0.189
# File started at 14:49:30, now at 16:50:17.
# 3772 9 Loss=0.028 Time=0.137
# File started at 14:49:30, now at 16:50:17.
# 3772 10 Loss=0.028 Time=0.182
# File started at 14:49:30, now at 16:50:18.
# 3773 1 Loss=0.030 Time=0.141
# File started at 14:49:30, now at 16:50:18.
# 3773 2 Loss=0.030 Time=0.138
# File started at 14:49:30, now at 16:50:18.
# 3773 3 Loss=0.031 Time=0.116
# File started at 14:49:30, now at 16:50:19.
# 3773 4 Loss=0.031 Time=0.139
# File started at 14:49:30, now at 16:50:19.
# 3773 5 Loss=0.030 Time=0.118
# File started at 14:49:30, now at 16:50:19.
# 3773 6 Loss=0.030 Time=0.146
# File started at 14:49:30, now at 16:50:19.
# 3773 7 Loss=0.031 Time=0.142
# File started at 14:49:30, now at 16:50:19.
# 3773 8 Loss=0.031 Time=0.118
# File started at 14:49:30, now at 16:50:19.
# 3773 9 Loss=0.033 Time=0.115
# File started at 14:49:30, now at 16:50:19.
# 3773 10 Loss=0.033 Time=0.140
# File started at 14:49:30, now at 16:50:20.
# 3774 1 Loss=0.032 Time=0.109
# File started at 14:49:30, now at 16:50:20.
# 3774 2 Loss=0.031 Time=0.117
# File started at 14:49:30, now at 16:50:20.
# 3774 3 Loss=0.031 Time=0.141
# File started at 14:49:30, now at 16:50:20.
# 3774 4 Loss=0.031 Time=0.109
# File started at 14:49:30, now at 16:50:21.
# 3774 5 Loss=0.033 Time=0.138
# File started at 14:49:30, now at 16:50:21.
# 3774 6 Loss=0.034 Time=0.141
# File started at 14:49:30, now at 16:50:21.
# 3774 7 Loss=0.034 Time=0.140
# File started at 14:49:30, now at 16:50:21.
# 3774 8 Loss=0.034 Time=0.111
# File started at 14:49:30, now at 16:50:21.
# 3774 9 Loss=0.034 Time=0.147
# File started at 14:49:30, now at 16:50:21.
# 3774 10 Loss=0.035 Time=0.142
# File started at 14:49:30, now at 16:50:22.
# 3775 1 Loss=0.034 Time=0.108
# File started at 14:49:30, now at 16:50:22.
# 3775 2 Loss=0.032 Time=0.146
# File started at 14:49:30, now at 16:50:22.
# 3775 3 Loss=0.031 Time=0.142
# File started at 14:49:30, now at 16:50:22.
# 3775 4 Loss=0.031 Time=0.140
# File started at 14:49:30, now at 16:50:22.
# 3775 5 Loss=0.031 Time=0.118
# File started at 14:49:30, now at 16:50:23.
# 3775 6 Loss=0.031 Time=0.143
# File started at 14:49:30, now at 16:50:23.
# 3775 7 Loss=0.030 Time=0.140
# File started at 14:49:30, now at 16:50:23.
# 3775 8 Loss=0.030 Time=0.117
# File started at 14:49:30, now at 16:50:23.
# 3775 9 Loss=0.030 Time=0.142
# File started at 14:49:30, now at 16:50:23.
# 3775 10 Loss=0.030 Time=0.137
# File started at 14:49:30, now at 16:50:24.
# 3776 1 Loss=0.030 Time=0.116
# File started at 14:49:30, now at 16:50:24.
# 3776 2 Loss=0.031 Time=0.120
# File started at 14:49:30, now at 16:50:24.
# 3776 3 Loss=0.034 Time=0.110
# File started at 14:49:30, now at 16:50:24.
# 3776 4 Loss=0.033 Time=0.115
# File started at 14:49:30, now at 16:50:24.
# 3776 5 Loss=0.033 Time=0.111
# File started at 14:49:30, now at 16:50:24.
# 3776 6 Loss=0.033 Time=0.140
# File started at 14:49:30, now at 16:50:25.
# 3776 7 Loss=0.033 Time=0.110
# File started at 14:49:30, now at 16:50:25.
# 3776 8 Loss=0.032 Time=0.138
# File started at 14:49:30, now at 16:50:25.
# 3776 9 Loss=0.033 Time=0.146
# File started at 14:49:30, now at 16:50:25.
# 3776 10 Loss=0.033 Time=0.119
# File started at 14:49:30, now at 16:50:26.
# 3777 1 Loss=0.034 Time=0.142
# File started at 14:49:30, now at 16:50:26.
# 3777 2 Loss=0.034 Time=0.116
# File started at 14:49:30, now at 16:50:26.
# 3777 3 Loss=0.034 Time=0.117
# File started at 14:49:30, now at 16:50:26.
# 3777 4 Loss=0.033 Time=0.152
# File started at 14:49:30, now at 16:50:26.
# 3777 5 Loss=0.034 Time=0.109
# File started at 14:49:30, now at 16:50:26.
# 3777 6 Loss=0.034 Time=0.110
# File started at 14:49:30, now at 16:50:27.
# 3777 7 Loss=0.034 Time=0.144
# File started at 14:49:30, now at 16:50:27.
# 3777 8 Loss=0.033 Time=0.110
# File started at 14:49:30, now at 16:50:27.
# 3777 9 Loss=0.034 Time=0.146
# File started at 14:49:30, now at 16:50:27.
# 3777 10 Loss=0.033 Time=0.149
# File started at 14:49:30, now at 16:50:28.
# 3778 1 Loss=0.033 Time=0.111
# File started at 14:49:30, now at 16:50:28.
# 3778 2 Loss=0.034 Time=0.126
# File started at 14:49:30, now at 16:50:28.
# 3778 3 Loss=0.033 Time=0.126
# File started at 14:49:30, now at 16:50:28.
# 3778 4 Loss=0.033 Time=0.173
# File started at 14:49:30, now at 16:50:28.
# 3778 5 Loss=0.033 Time=0.116
# File started at 14:49:30, now at 16:50:28.
# 3778 6 Loss=0.032 Time=0.116
# File started at 14:49:30, now at 16:50:28.
# 3778 7 Loss=0.031 Time=0.118
# File started at 14:49:30, now at 16:50:29.
# 3778 8 Loss=0.031 Time=0.117
# File started at 14:49:30, now at 16:50:29.
# 3778 9 Loss=0.031 Time=0.175
# File started at 14:49:30, now at 16:50:29.
# 3778 10 Loss=0.032 Time=0.176
# File started at 14:49:30, now at 16:50:30.
# 3779 1 Loss=0.031 Time=0.172
# File started at 14:49:30, now at 16:50:30.
# 3779 2 Loss=0.032 Time=0.176
# File started at 14:49:30, now at 16:50:30.
# 3779 3 Loss=0.032 Time=0.135
# File started at 14:49:30, now at 16:50:30.
# 3779 4 Loss=0.032 Time=0.176
# File started at 14:49:30, now at 16:50:31.
# 3779 5 Loss=0.031 Time=0.115
# File started at 14:49:30, now at 16:50:31.
# 3779 6 Loss=0.033 Time=0.116
# File started at 14:49:30, now at 16:50:31.
# 3779 7 Loss=0.033 Time=0.170
# File started at 14:49:30, now at 16:50:31.
# 3779 8 Loss=0.031 Time=0.174
# File started at 14:49:30, now at 16:50:31.
# 3779 9 Loss=0.030 Time=0.111
# File started at 14:49:30, now at 16:50:31.
# 3779 10 Loss=0.030 Time=0.145
# File started at 14:49:30, now at 16:50:32.
# 3780 1 Loss=0.030 Time=0.143
# File started at 14:49:30, now at 16:50:32.
# 3780 2 Loss=0.029 Time=0.146
# File started at 14:49:30, now at 16:50:32.
# 3780 3 Loss=0.029 Time=0.140
# File started at 14:49:30, now at 16:50:32.
# 3780 4 Loss=0.029 Time=0.144
# File started at 14:49:30, now at 16:50:33.
# 3780 5 Loss=0.029 Time=0.142
# File started at 14:49:30, now at 16:50:33.
# 3780 6 Loss=0.030 Time=0.140
# File started at 14:49:30, now at 16:50:33.
# 3780 7 Loss=0.030 Time=0.117
# File started at 14:49:30, now at 16:50:33.
# 3780 8 Loss=0.032 Time=0.148
# File started at 14:49:30, now at 16:50:33.
# 3780 9 Loss=0.032 Time=0.110
# File started at 14:49:30, now at 16:50:33.
# 3780 10 Loss=0.031 Time=0.147
# File started at 14:49:30, now at 16:50:34.
# 3781 1 Loss=0.032 Time=0.143
# File started at 14:49:30, now at 16:50:34.
# 3781 2 Loss=0.029 Time=0.118
# File started at 14:49:30, now at 16:50:34.
# 3781 3 Loss=0.030 Time=0.147
# File started at 14:49:30, now at 16:50:34.
# 3781 4 Loss=0.030 Time=0.110
# File started at 14:49:30, now at 16:50:35.
# 3781 5 Loss=0.030 Time=0.110
# File started at 14:49:30, now at 16:50:35.
# 3781 6 Loss=0.031 Time=0.110
# File started at 14:49:30, now at 16:50:35.
# 3781 7 Loss=0.031 Time=0.117
# File started at 14:49:30, now at 16:50:35.
# 3781 8 Loss=0.031 Time=0.110
# File started at 14:49:30, now at 16:50:35.
# 3781 9 Loss=0.031 Time=0.120
# File started at 14:49:30, now at 16:50:35.
# 3781 10 Loss=0.032 Time=0.123
# File started at 14:49:30, now at 16:50:36.
# 3782 1 Loss=0.032 Time=0.118
# File started at 14:49:30, now at 16:50:36.
# 3782 2 Loss=0.033 Time=0.142
# File started at 14:49:30, now at 16:50:36.
# 3782 3 Loss=0.030 Time=0.141
# File started at 14:49:30, now at 16:50:36.
# 3782 4 Loss=0.031 Time=0.148
# File started at 14:49:30, now at 16:50:36.
# 3782 5 Loss=0.030 Time=0.109
# File started at 14:49:30, now at 16:50:36.
# 3782 6 Loss=0.031 Time=0.136
# File started at 14:49:30, now at 16:50:37.
# 3782 7 Loss=0.031 Time=0.118
# File started at 14:49:30, now at 16:50:37.
# 3782 8 Loss=0.034 Time=0.111
# File started at 14:49:30, now at 16:50:37.
# 3782 9 Loss=0.034 Time=0.148
# File started at 14:49:30, now at 16:50:37.
# 3782 10 Loss=0.034 Time=0.144
# File started at 14:49:30, now at 16:50:38.
# 3783 1 Loss=0.034 Time=0.144
# File started at 14:49:30, now at 16:50:38.
# 3783 2 Loss=0.033 Time=0.118
# File started at 14:49:30, now at 16:50:38.
# 3783 3 Loss=0.033 Time=0.142
# File started at 14:49:30, now at 16:50:38.
# 3783 4 Loss=0.031 Time=0.143
# File started at 14:49:30, now at 16:50:38.
# 3783 5 Loss=0.028 Time=0.116
# File started at 14:49:30, now at 16:50:38.
# 3783 6 Loss=0.028 Time=0.159
# File started at 14:49:30, now at 16:50:39.
# 3783 7 Loss=0.028 Time=0.147
# File started at 14:49:30, now at 16:50:39.
# 3783 8 Loss=0.028 Time=0.115
# File started at 14:49:30, now at 16:50:39.
# 3783 9 Loss=0.027 Time=0.111
# File started at 14:49:30, now at 16:50:39.
# 3783 10 Loss=0.027 Time=0.143
# File started at 14:49:30, now at 16:50:40.
# 3784 1 Loss=0.028 Time=0.145
# File started at 14:49:30, now at 16:50:40.
# 3784 2 Loss=0.028 Time=0.109
# File started at 14:49:30, now at 16:50:40.
# 3784 3 Loss=0.028 Time=0.141
# File started at 14:49:30, now at 16:50:40.
# 3784 4 Loss=0.029 Time=0.142
# File started at 14:49:30, now at 16:50:40.
# 3784 5 Loss=0.029 Time=0.138
# File started at 14:49:30, now at 16:50:40.
# 3784 6 Loss=0.032 Time=0.143
# File started at 14:49:30, now at 16:50:41.
# 3784 7 Loss=0.032 Time=0.145
# File started at 14:49:30, now at 16:50:41.
# 3784 8 Loss=0.032 Time=0.110
# File started at 14:49:30, now at 16:50:41.
# 3784 9 Loss=0.032 Time=0.147
# File started at 14:49:30, now at 16:50:41.
# 3784 10 Loss=0.033 Time=0.148
# File started at 14:49:30, now at 16:50:42.
# 3785 1 Loss=0.032 Time=0.127
# File started at 14:49:30, now at 16:50:42.
# 3785 2 Loss=0.033 Time=0.169
# File started at 14:49:30, now at 16:50:42.
# 3785 3 Loss=0.033 Time=0.128
# File started at 14:49:30, now at 16:50:42.
# 3785 4 Loss=0.033 Time=0.131
# File started at 14:49:30, now at 16:50:43.
# 3785 5 Loss=0.035 Time=0.115
# File started at 14:49:30, now at 16:50:43.
# 3785 6 Loss=0.035 Time=0.129
# File started at 14:49:30, now at 16:50:43.
# 3785 7 Loss=0.035 Time=0.183
# File started at 14:49:30, now at 16:50:43.
# 3785 8 Loss=0.034 Time=0.171
# File started at 14:49:30, now at 16:50:43.
# 3785 9 Loss=0.034 Time=0.174
# File started at 14:49:30, now at 16:50:43.
# 3785 10 Loss=0.034 Time=0.127
# File started at 14:49:30, now at 16:50:44.
# 3786 1 Loss=0.034 Time=0.262
# File started at 14:49:30, now at 16:50:45.
# 3786 2 Loss=0.034 Time=0.156
# File started at 14:49:30, now at 16:50:45.
# 3786 3 Loss=0.033 Time=0.147
# File started at 14:49:30, now at 16:50:45.
# 3786 4 Loss=0.034 Time=0.117
# File started at 14:49:30, now at 16:50:45.
# 3786 5 Loss=0.034 Time=0.141
# File started at 14:49:30, now at 16:50:45.
# 3786 6 Loss=0.032 Time=0.118
# File started at 14:49:30, now at 16:50:45.
# 3786 7 Loss=0.033 Time=0.111
# File started at 14:49:30, now at 16:50:45.
# 3786 8 Loss=0.034 Time=0.117
# File started at 14:49:30, now at 16:50:46.
# 3786 9 Loss=0.034 Time=0.147
# File started at 14:49:30, now at 16:50:46.
# 3786 10 Loss=0.033 Time=0.117
# File started at 14:49:30, now at 16:50:46.
# 3787 1 Loss=0.033 Time=0.142
# File started at 14:49:30, now at 16:50:46.
# 3787 2 Loss=0.033 Time=0.116
# File started at 14:49:30, now at 16:50:47.
# 3787 3 Loss=0.033 Time=0.118
# File started at 14:49:30, now at 16:50:47.
# 3787 4 Loss=0.033 Time=0.145
# File started at 14:49:30, now at 16:50:47.
# 3787 5 Loss=0.033 Time=0.142
# File started at 14:49:30, now at 16:50:47.
# 3787 6 Loss=0.033 Time=0.143
# File started at 14:49:30, now at 16:50:47.
# 3787 7 Loss=0.031 Time=0.122
# File started at 14:49:30, now at 16:50:47.
# 3787 8 Loss=0.032 Time=0.148
# File started at 14:49:30, now at 16:50:47.
# 3787 9 Loss=0.032 Time=0.146
# File started at 14:49:30, now at 16:50:48.
# 3787 10 Loss=0.032 Time=0.144
# File started at 14:49:30, now at 16:50:48.
# 3788 1 Loss=0.031 Time=0.142
# File started at 14:49:30, now at 16:50:48.
# 3788 2 Loss=0.032 Time=0.143
# File started at 14:49:30, now at 16:50:49.
# 3788 3 Loss=0.032 Time=0.138
# File started at 14:49:30, now at 16:50:49.
# 3788 4 Loss=0.033 Time=0.139
# File started at 14:49:30, now at 16:50:49.
# 3788 5 Loss=0.033 Time=0.142
# File started at 14:49:30, now at 16:50:49.
# 3788 6 Loss=0.033 Time=0.144
# File started at 14:49:30, now at 16:50:49.
# 3788 7 Loss=0.034 Time=0.114
# File started at 14:49:30, now at 16:50:49.
# 3788 8 Loss=0.032 Time=0.116
# File started at 14:49:30, now at 16:50:49.
# 3788 9 Loss=0.032 Time=0.142
# File started at 14:49:30, now at 16:50:50.
# 3788 10 Loss=0.032 Time=0.142
# File started at 14:49:30, now at 16:50:50.
# 3789 1 Loss=0.032 Time=0.143
# File started at 14:49:30, now at 16:50:50.
# 3789 2 Loss=0.031 Time=0.118
# File started at 14:49:30, now at 16:50:51.
# 3789 3 Loss=0.033 Time=0.144
# File started at 14:49:30, now at 16:50:51.
# 3789 4 Loss=0.032 Time=0.109
# File started at 14:49:30, now at 16:50:51.
# 3789 5 Loss=0.034 Time=0.142
# File started at 14:49:30, now at 16:50:51.
# 3789 6 Loss=0.034 Time=0.138
# File started at 14:49:30, now at 16:50:51.
# 3789 7 Loss=0.034 Time=0.142
# File started at 14:49:30, now at 16:50:51.
# 3789 8 Loss=0.034 Time=0.145
# File started at 14:49:30, now at 16:50:51.
# 3789 9 Loss=0.033 Time=0.109
# File started at 14:49:30, now at 16:50:51.
# 3789 10 Loss=0.033 Time=0.113
# File started at 14:49:30, now at 16:50:52.
# 3790 1 Loss=0.033 Time=0.109
# File started at 14:49:30, now at 16:50:52.
# 3790 2 Loss=0.033 Time=0.144
# File started at 14:49:30, now at 16:50:52.
# 3790 3 Loss=0.033 Time=0.117
# File started at 14:49:30, now at 16:50:53.
# 3790 4 Loss=0.033 Time=0.144
# File started at 14:49:30, now at 16:50:53.
# 3790 5 Loss=0.032 Time=0.110
# File started at 14:49:30, now at 16:50:53.
# 3790 6 Loss=0.032 Time=0.145
# File started at 14:49:30, now at 16:50:53.
# 3790 7 Loss=0.034 Time=0.109
# File started at 14:49:30, now at 16:50:53.
# 3790 8 Loss=0.035 Time=0.117
# File started at 14:49:30, now at 16:50:53.
# 3790 9 Loss=0.035 Time=0.111
# File started at 14:49:30, now at 16:50:53.
# 3790 10 Loss=0.035 Time=0.109
# File started at 14:49:30, now at 16:50:54.
# 3791 1 Loss=0.035 Time=0.139
# File started at 14:49:30, now at 16:50:54.
# 3791 2 Loss=0.035 Time=0.112
# File started at 14:49:30, now at 16:50:54.
# 3791 3 Loss=0.035 Time=0.146
# File started at 14:49:30, now at 16:50:54.
# 3791 4 Loss=0.034 Time=0.109
# File started at 14:49:30, now at 16:50:55.
# 3791 5 Loss=0.034 Time=0.147
# File started at 14:49:30, now at 16:50:55.
# 3791 6 Loss=0.035 Time=0.118
# File started at 14:49:30, now at 16:50:55.
# 3791 7 Loss=0.034 Time=0.198
# File started at 14:49:30, now at 16:50:55.
# 3791 8 Loss=0.034 Time=0.174
# File started at 14:49:30, now at 16:50:55.
# 3791 9 Loss=0.034 Time=0.186
# File started at 14:49:30, now at 16:50:55.
# 3791 10 Loss=0.033 Time=0.130
# File started at 14:49:30, now at 16:50:56.
# 3792 1 Loss=0.033 Time=0.126
# File started at 14:49:30, now at 16:50:57.
# 3792 2 Loss=0.033 Time=0.170
# File started at 14:49:30, now at 16:50:57.
# 3792 3 Loss=0.034 Time=0.131
# File started at 14:49:30, now at 16:50:57.
# 3792 4 Loss=0.034 Time=0.174
# File started at 14:49:30, now at 16:50:57.
# 3792 5 Loss=0.034 Time=0.116
# File started at 14:49:30, now at 16:50:57.
# 3792 6 Loss=0.035 Time=0.176
# File started at 14:49:30, now at 16:50:57.
# 3792 7 Loss=0.035 Time=0.118
# File started at 14:49:30, now at 16:50:57.
# 3792 8 Loss=0.034 Time=0.168
# File started at 14:49:30, now at 16:50:58.
# 3792 9 Loss=0.033 Time=0.184
# File started at 14:49:30, now at 16:50:58.
# 3792 10 Loss=0.035 Time=0.115
# File started at 14:49:30, now at 16:50:59.
# 3793 1 Loss=0.034 Time=0.140
# File started at 14:49:30, now at 16:50:59.
# 3793 2 Loss=0.034 Time=0.110
# File started at 14:49:30, now at 16:50:59.
# 3793 3 Loss=0.035 Time=0.110
# File started at 14:49:30, now at 16:50:59.
# 3793 4 Loss=0.032 Time=0.149
# File started at 14:49:30, now at 16:50:59.
# 3793 5 Loss=0.033 Time=0.113
# File started at 14:49:30, now at 16:50:59.
# 3793 6 Loss=0.033 Time=0.116
# File started at 14:49:30, now at 16:50:59.
# 3793 7 Loss=0.033 Time=0.143
# File started at 14:49:30, now at 16:50:59.
# 3793 8 Loss=0.031 Time=0.146
# File started at 14:49:30, now at 16:51:00.
# 3793 9 Loss=0.031 Time=0.148
# File started at 14:49:30, now at 16:51:00.
# 3793 10 Loss=0.031 Time=0.144
# File started at 14:49:30, now at 16:51:01.
# 3794 1 Loss=0.032 Time=0.148
# File started at 14:49:30, now at 16:51:01.
# 3794 2 Loss=0.032 Time=0.142
# File started at 14:49:30, now at 16:51:01.
# 3794 3 Loss=0.032 Time=0.142
# File started at 14:49:30, now at 16:51:01.
# 3794 4 Loss=0.032 Time=0.117
# File started at 14:49:30, now at 16:51:01.
# 3794 5 Loss=0.034 Time=0.140
# File started at 14:49:30, now at 16:51:01.
# 3794 6 Loss=0.035 Time=0.109
# File started at 14:49:30, now at 16:51:01.
# 3794 7 Loss=0.036 Time=0.109
# File started at 14:49:30, now at 16:51:01.
# 3794 8 Loss=0.035 Time=0.117
# File started at 14:49:30, now at 16:51:02.
# 3794 9 Loss=0.034 Time=0.141
# File started at 14:49:30, now at 16:51:02.
# 3794 10 Loss=0.033 Time=0.138
# File started at 14:49:30, now at 16:51:02.
# 3795 1 Loss=0.032 Time=0.143
# File started at 14:49:30, now at 16:51:03.
# 3795 2 Loss=0.034 Time=0.108
# File started at 14:49:30, now at 16:51:03.
# 3795 3 Loss=0.034 Time=0.142
# File started at 14:49:30, now at 16:51:03.
# 3795 4 Loss=0.035 Time=0.117
# File started at 14:49:30, now at 16:51:03.
# 3795 5 Loss=0.035 Time=0.115
# File started at 14:49:30, now at 16:51:03.
# 3795 6 Loss=0.034 Time=0.143
# File started at 14:49:30, now at 16:51:03.
# 3795 7 Loss=0.036 Time=0.110
# File started at 14:49:30, now at 16:51:03.
# 3795 8 Loss=0.035 Time=0.147
# File started at 14:49:30, now at 16:51:03.
# 3795 9 Loss=0.037 Time=0.139
# File started at 14:49:30, now at 16:51:04.
# 3795 10 Loss=0.036 Time=0.141
# File started at 14:49:30, now at 16:51:04.
# 3796 1 Loss=0.038 Time=0.107
# File started at 14:49:30, now at 16:51:04.
# 3796 2 Loss=0.036 Time=0.116
# File started at 14:49:30, now at 16:51:05.
# 3796 3 Loss=0.036 Time=0.143
# File started at 14:49:30, now at 16:51:05.
# 3796 4 Loss=0.035 Time=0.113
# File started at 14:49:30, now at 16:51:05.
# 3796 5 Loss=0.035 Time=0.141
# File started at 14:49:30, now at 16:51:05.
# 3796 6 Loss=0.035 Time=0.116
# File started at 14:49:30, now at 16:51:05.
# 3796 7 Loss=0.036 Time=0.112
# File started at 14:49:30, now at 16:51:05.
# 3796 8 Loss=0.035 Time=0.143
# File started at 14:49:30, now at 16:51:05.
# 3796 9 Loss=0.035 Time=0.144
# File started at 14:49:30, now at 16:51:05.
# 3796 10 Loss=0.035 Time=0.116
# File started at 14:49:30, now at 16:51:06.
# 3797 1 Loss=0.034 Time=0.144
# File started at 14:49:30, now at 16:51:06.
# 3797 2 Loss=0.035 Time=0.150
# File started at 14:49:30, now at 16:51:07.
# 3797 3 Loss=0.034 Time=0.141
# File started at 14:49:30, now at 16:51:07.
# 3797 4 Loss=0.035 Time=0.144
# File started at 14:49:30, now at 16:51:07.
# 3797 5 Loss=0.033 Time=0.155
# File started at 14:49:30, now at 16:51:07.
# 3797 6 Loss=0.033 Time=0.151
# File started at 14:49:30, now at 16:51:07.
# 3797 7 Loss=0.033 Time=0.150
# File started at 14:49:30, now at 16:51:07.
# 3797 8 Loss=0.032 Time=0.141
# File started at 14:49:30, now at 16:51:07.
# 3797 9 Loss=0.032 Time=0.110
# File started at 14:49:30, now at 16:51:08.
# 3797 10 Loss=0.032 Time=0.143
# File started at 14:49:30, now at 16:51:08.
# 3798 1 Loss=0.032 Time=0.172
# File started at 14:49:30, now at 16:51:09.
# 3798 2 Loss=0.033 Time=0.128
# File started at 14:49:30, now at 16:51:09.
# 3798 3 Loss=0.032 Time=0.117
# File started at 14:49:30, now at 16:51:09.
# 3798 4 Loss=0.031 Time=0.112
# File started at 14:49:30, now at 16:51:09.
# 3798 5 Loss=0.031 Time=0.187
# File started at 14:49:30, now at 16:51:09.
# 3798 6 Loss=0.032 Time=0.174
# File started at 14:49:30, now at 16:51:09.
# 3798 7 Loss=0.032 Time=0.135
# File started at 14:49:30, now at 16:51:09.
# 3798 8 Loss=0.033 Time=0.117
# File started at 14:49:30, now at 16:51:10.
# 3798 9 Loss=0.033 Time=0.129
# File started at 14:49:30, now at 16:51:10.
# 3798 10 Loss=0.033 Time=0.180
# File started at 14:49:30, now at 16:51:11.
# 3799 1 Loss=0.033 Time=0.165
# File started at 14:49:30, now at 16:51:11.
# 3799 2 Loss=0.033 Time=0.172
# File started at 14:49:30, now at 16:51:11.
# 3799 3 Loss=0.033 Time=0.115
# File started at 14:49:30, now at 16:51:11.
# 3799 4 Loss=0.032 Time=0.181
# File started at 14:49:30, now at 16:51:11.
# 3799 5 Loss=0.033 Time=0.119
# File started at 14:49:30, now at 16:51:11.
# 3799 6 Loss=0.033 Time=0.110
# File started at 14:49:30, now at 16:51:12.
# 3799 7 Loss=0.033 Time=0.112
# File started at 14:49:30, now at 16:51:12.
# 3799 8 Loss=0.033 Time=0.117
# File started at 14:49:30, now at 16:51:12.
# 3799 9 Loss=0.033 Time=0.117
# File started at 14:49:30, now at 16:51:12.
# 3799 10 Loss=0.032 Time=0.140
# File started at 14:49:30, now at 16:51:13.
# 3800 1 Loss=0.031 Time=0.144
# File started at 14:49:30, now at 16:51:13.
# 3800 2 Loss=0.031 Time=0.116
# File started at 14:49:30, now at 16:51:13.
# 3800 3 Loss=0.031 Time=0.108
# File started at 14:49:30, now at 16:51:13.
# 3800 4 Loss=0.031 Time=0.149
# File started at 14:49:30, now at 16:51:13.
# 3800 5 Loss=0.030 Time=0.145
# File started at 14:49:30, now at 16:51:13.
# 3800 6 Loss=0.029 Time=0.120
# File started at 14:49:30, now at 16:51:13.
# 3800 7 Loss=0.029 Time=0.117
# File started at 14:49:30, now at 16:51:14.
# 3800 8 Loss=0.030 Time=0.117
# File started at 14:49:30, now at 16:51:14.
# 3800 9 Loss=0.030 Time=0.139
# File started at 14:49:30, now at 16:51:14.
# 3800 10 Loss=0.031 Time=0.108
# File started at 14:49:30, now at 16:51:15.
# 3801 1 Loss=0.034 Time=0.110
# File started at 14:49:30, now at 16:51:15.
# 3801 2 Loss=0.034 Time=0.118
# File started at 14:49:30, now at 16:51:15.
# 3801 3 Loss=0.035 Time=0.110
# File started at 14:49:30, now at 16:51:15.
# 3801 4 Loss=0.035 Time=0.148
# File started at 14:49:30, now at 16:51:15.
# 3801 5 Loss=0.034 Time=0.119
# File started at 14:49:30, now at 16:51:15.
# 3801 6 Loss=0.035 Time=0.143
# File started at 14:49:30, now at 16:51:15.
# 3801 7 Loss=0.035 Time=0.116
# File started at 14:49:30, now at 16:51:15.
# 3801 8 Loss=0.034 Time=0.145
# File started at 14:49:30, now at 16:51:16.
# 3801 9 Loss=0.034 Time=0.142
# File started at 14:49:30, now at 16:51:16.
# 3801 10 Loss=0.034 Time=0.141
# File started at 14:49:30, now at 16:51:16.
# 3802 1 Loss=0.033 Time=0.109
# File started at 14:49:30, now at 16:51:17.
# 3802 2 Loss=0.033 Time=0.116
# File started at 14:49:30, now at 16:51:17.
# 3802 3 Loss=0.033 Time=0.111
# File started at 14:49:30, now at 16:51:17.
# 3802 4 Loss=0.033 Time=0.141
# File started at 14:49:30, now at 16:51:17.
# 3802 5 Loss=0.034 Time=0.110
# File started at 14:49:30, now at 16:51:17.
# 3802 6 Loss=0.034 Time=0.113
# File started at 14:49:30, now at 16:51:17.
# 3802 7 Loss=0.033 Time=0.118
# File started at 14:49:30, now at 16:51:17.
# 3802 8 Loss=0.030 Time=0.146
# File started at 14:49:30, now at 16:51:17.
# 3802 9 Loss=0.030 Time=0.111
# File started at 14:49:30, now at 16:51:18.
# 3802 10 Loss=0.030 Time=0.110
# File started at 14:49:30, now at 16:51:18.
# 3803 1 Loss=0.030 Time=0.117
# File started at 14:49:30, now at 16:51:19.
# 3803 2 Loss=0.030 Time=0.140
# File started at 14:49:30, now at 16:51:19.
# 3803 3 Loss=0.030 Time=0.109
# File started at 14:49:30, now at 16:51:19.
# 3803 4 Loss=0.030 Time=0.141
# File started at 14:49:30, now at 16:51:19.
# 3803 5 Loss=0.030 Time=0.110
# File started at 14:49:30, now at 16:51:19.
# 3803 6 Loss=0.030 Time=0.118
# File started at 14:49:30, now at 16:51:19.
# 3803 7 Loss=0.032 Time=0.147
# File started at 14:49:30, now at 16:51:19.
# 3803 8 Loss=0.033 Time=0.151
# File started at 14:49:30, now at 16:51:20.
# 3803 9 Loss=0.031 Time=0.166
# File started at 14:49:30, now at 16:51:20.
# 3803 10 Loss=0.032 Time=0.110
# File started at 14:49:30, now at 16:51:20.
# 3804 1 Loss=0.031 Time=0.117
# File started at 14:49:30, now at 16:51:20.
# 3804 2 Loss=0.030 Time=0.142
# File started at 14:49:30, now at 16:51:21.
# 3804 3 Loss=0.031 Time=0.119
# File started at 14:49:30, now at 16:51:21.
# 3804 4 Loss=0.032 Time=0.143
# File started at 14:49:30, now at 16:51:21.
# 3804 5 Loss=0.034 Time=0.149
# File started at 14:49:30, now at 16:51:21.
# 3804 6 Loss=0.036 Time=0.114
# File started at 14:49:30, now at 16:51:21.
# 3804 7 Loss=0.036 Time=0.116
# File started at 14:49:30, now at 16:51:21.
# 3804 8 Loss=0.036 Time=0.117
# File started at 14:49:30, now at 16:51:21.
# 3804 9 Loss=0.035 Time=0.117
# File started at 14:49:30, now at 16:51:21.
# 3804 10 Loss=0.036 Time=0.130
# File started at 14:49:30, now at 16:51:22.
# 3805 1 Loss=0.036 Time=0.116
# File started at 14:49:30, now at 16:51:22.
# 3805 2 Loss=0.036 Time=0.128
# File started at 14:49:30, now at 16:51:23.
# 3805 3 Loss=0.033 Time=0.118
# File started at 14:49:30, now at 16:51:23.
# 3805 4 Loss=0.033 Time=0.178
# File started at 14:49:30, now at 16:51:23.
# 3805 5 Loss=0.031 Time=0.186
# File started at 14:49:30, now at 16:51:23.
# 3805 6 Loss=0.031 Time=0.130
# File started at 14:49:30, now at 16:51:23.
# 3805 7 Loss=0.031 Time=0.117
# File started at 14:49:30, now at 16:51:23.
# 3805 8 Loss=0.031 Time=0.129
# File started at 14:49:30, now at 16:51:23.
# 3805 9 Loss=0.030 Time=0.119
# File started at 14:49:30, now at 16:51:24.
# 3805 10 Loss=0.031 Time=0.186
# File started at 14:49:30, now at 16:51:25.
# 3806 1 Loss=0.031 Time=0.193
# File started at 14:49:30, now at 16:51:25.
# 3806 2 Loss=0.031 Time=0.110
# File started at 14:49:30, now at 16:51:25.
# 3806 3 Loss=0.031 Time=0.109
# File started at 14:49:30, now at 16:51:25.
# 3806 4 Loss=0.031 Time=0.116
# File started at 14:49:30, now at 16:51:25.
# 3806 5 Loss=0.031 Time=0.154
# File started at 14:49:30, now at 16:51:25.
# 3806 6 Loss=0.031 Time=0.145
# File started at 14:49:30, now at 16:51:25.
# 3806 7 Loss=0.031 Time=0.144
# File started at 14:49:30, now at 16:51:26.
# 3806 8 Loss=0.031 Time=0.138
# File started at 14:49:30, now at 16:51:26.
# 3806 9 Loss=0.029 Time=0.141
# File started at 14:49:30, now at 16:51:26.
# 3806 10 Loss=0.029 Time=0.117
# File started at 14:49:30, now at 16:51:27.
# 3807 1 Loss=0.028 Time=0.142
# File started at 14:49:30, now at 16:51:27.
# 3807 2 Loss=0.028 Time=0.115
# File started at 14:49:30, now at 16:51:27.
# 3807 3 Loss=0.028 Time=0.110
# File started at 14:49:30, now at 16:51:27.
# 3807 4 Loss=0.029 Time=0.143
# File started at 14:49:30, now at 16:51:27.
# 3807 5 Loss=0.030 Time=0.140
# File started at 14:49:30, now at 16:51:27.
# 3807 6 Loss=0.030 Time=0.112
# File started at 14:49:30, now at 16:51:27.
# 3807 7 Loss=0.031 Time=0.108
# File started at 14:49:30, now at 16:51:27.
# 3807 8 Loss=0.034 Time=0.111
# File started at 14:49:30, now at 16:51:28.
# 3807 9 Loss=0.034 Time=0.143
# File started at 14:49:30, now at 16:51:28.
# 3807 10 Loss=0.034 Time=0.140
# File started at 14:49:30, now at 16:51:28.
# 3808 1 Loss=0.034 Time=0.110
# File started at 14:49:30, now at 16:51:29.
# 3808 2 Loss=0.034 Time=0.108
# File started at 14:49:30, now at 16:51:29.
# 3808 3 Loss=0.034 Time=0.141
# File started at 14:49:30, now at 16:51:29.
# 3808 4 Loss=0.034 Time=0.146
# File started at 14:49:30, now at 16:51:29.
# 3808 5 Loss=0.035 Time=0.140
# File started at 14:49:30, now at 16:51:29.
# 3808 6 Loss=0.034 Time=0.117
# File started at 14:49:30, now at 16:51:29.
# 3808 7 Loss=0.034 Time=0.115
# File started at 14:49:30, now at 16:51:29.
# 3808 8 Loss=0.033 Time=0.136
# File started at 14:49:30, now at 16:51:29.
# 3808 9 Loss=0.034 Time=0.116
# File started at 14:49:30, now at 16:51:30.
# 3808 10 Loss=0.034 Time=0.145
# File started at 14:49:30, now at 16:51:30.
# 3809 1 Loss=0.034 Time=0.107
# File started at 14:49:30, now at 16:51:30.
# 3809 2 Loss=0.034 Time=0.152
# File started at 14:49:30, now at 16:51:31.
# 3809 3 Loss=0.034 Time=0.117
# File started at 14:49:30, now at 16:51:31.
# 3809 4 Loss=0.032 Time=0.111
# File started at 14:49:30, now at 16:51:31.
# 3809 5 Loss=0.032 Time=0.110
# File started at 14:49:30, now at 16:51:31.
# 3809 6 Loss=0.030 Time=0.112
# File started at 14:49:30, now at 16:51:31.
# 3809 7 Loss=0.030 Time=0.147
# File started at 14:49:30, now at 16:51:31.
# 3809 8 Loss=0.029 Time=0.140
# File started at 14:49:30, now at 16:51:31.
# 3809 9 Loss=0.027 Time=0.110
# File started at 14:49:30, now at 16:51:31.
# 3809 10 Loss=0.026 Time=0.141
# File started at 14:49:30, now at 16:51:32.
# 3810 1 Loss=0.026 Time=0.108
# File started at 14:49:30, now at 16:51:32.
# 3810 2 Loss=0.025 Time=0.110
# File started at 14:49:30, now at 16:51:32.
# 3810 3 Loss=0.027 Time=0.144
# File started at 14:49:30, now at 16:51:32.
# 3810 4 Loss=0.028 Time=0.145
# File started at 14:49:30, now at 16:51:33.
# 3810 5 Loss=0.028 Time=0.147
# File started at 14:49:30, now at 16:51:33.
# 3810 6 Loss=0.028 Time=0.139
# File started at 14:49:30, now at 16:51:33.
# 3810 7 Loss=0.028 Time=0.116
# File started at 14:49:30, now at 16:51:33.
# 3810 8 Loss=0.029 Time=0.139
# File started at 14:49:30, now at 16:51:33.
# 3810 9 Loss=0.030 Time=0.147
# File started at 14:49:30, now at 16:51:33.
# 3810 10 Loss=0.031 Time=0.115
# File started at 14:49:30, now at 16:51:34.
# 3811 1 Loss=0.031 Time=0.146
# File started at 14:49:30, now at 16:51:34.
# 3811 2 Loss=0.033 Time=0.146
# File started at 14:49:30, now at 16:51:34.
# 3811 3 Loss=0.033 Time=0.110
# File started at 14:49:30, now at 16:51:34.
# 3811 4 Loss=0.033 Time=0.145
# File started at 14:49:30, now at 16:51:35.
# 3811 5 Loss=0.033 Time=0.111
# File started at 14:49:30, now at 16:51:35.
# 3811 6 Loss=0.033 Time=0.121
# File started at 14:49:30, now at 16:51:35.
# 3811 7 Loss=0.033 Time=0.191
# File started at 14:49:30, now at 16:51:35.
# 3811 8 Loss=0.035 Time=0.175
# File started at 14:49:30, now at 16:51:35.
# 3811 9 Loss=0.035 Time=0.177
# File started at 14:49:30, now at 16:51:35.
# 3811 10 Loss=0.035 Time=0.115
# File started at 14:49:30, now at 16:51:36.
# 3812 1 Loss=0.035 Time=0.178
# File started at 14:49:30, now at 16:51:36.
# 3812 2 Loss=0.035 Time=0.117
# File started at 14:49:30, now at 16:51:37.
# 3812 3 Loss=0.035 Time=0.114
# File started at 14:49:30, now at 16:51:37.
# 3812 4 Loss=0.034 Time=0.117
# File started at 14:49:30, now at 16:51:37.
# 3812 5 Loss=0.035 Time=0.115
# File started at 14:49:30, now at 16:51:37.
# 3812 6 Loss=0.035 Time=0.116
# File started at 14:49:30, now at 16:51:37.
# 3812 7 Loss=0.034 Time=0.182
# File started at 14:49:30, now at 16:51:37.
# 3812 8 Loss=0.033 Time=0.115
# File started at 14:49:30, now at 16:51:37.
# 3812 9 Loss=0.034 Time=0.176
# File started at 14:49:30, now at 16:51:38.
# 3812 10 Loss=0.032 Time=0.163
# File started at 14:49:30, now at 16:51:38.
# 3813 1 Loss=0.032 Time=0.116
# File started at 14:49:30, now at 16:51:39.
# 3813 2 Loss=0.032 Time=0.143
# File started at 14:49:30, now at 16:51:39.
# 3813 3 Loss=0.032 Time=0.146
# File started at 14:49:30, now at 16:51:39.
# 3813 4 Loss=0.033 Time=0.145
# File started at 14:49:30, now at 16:51:39.
# 3813 5 Loss=0.036 Time=0.149
# File started at 14:49:30, now at 16:51:39.
# 3813 6 Loss=0.036 Time=0.138
# File started at 14:49:30, now at 16:51:39.
# 3813 7 Loss=0.036 Time=0.148
# File started at 14:49:30, now at 16:51:39.
# 3813 8 Loss=0.036 Time=0.141
# File started at 14:49:30, now at 16:51:40.
# 3813 9 Loss=0.037 Time=0.140
# File started at 14:49:30, now at 16:51:40.
# 3813 10 Loss=0.037 Time=0.145
# File started at 14:49:30, now at 16:51:41.
# 3814 1 Loss=0.038 Time=0.108
# File started at 14:49:30, now at 16:51:41.
# 3814 2 Loss=0.037 Time=0.140
# File started at 14:49:30, now at 16:51:41.
# 3814 3 Loss=0.038 Time=0.109
# File started at 14:49:30, now at 16:51:41.
# 3814 4 Loss=0.039 Time=0.114
# File started at 14:49:30, now at 16:51:41.
# 3814 5 Loss=0.035 Time=0.108
# File started at 14:49:30, now at 16:51:41.
# 3814 6 Loss=0.034 Time=0.109
# File started at 14:49:30, now at 16:51:41.
# 3814 7 Loss=0.034 Time=0.109
# File started at 14:49:30, now at 16:51:41.
# 3814 8 Loss=0.035 Time=0.111
# File started at 14:49:30, now at 16:51:41.
# 3814 9 Loss=0.035 Time=0.117
# File started at 14:49:30, now at 16:51:42.
# 3814 10 Loss=0.035 Time=0.116
# File started at 14:49:30, now at 16:51:42.
# 3815 1 Loss=0.035 Time=0.142
# File started at 14:49:30, now at 16:51:42.
# 3815 2 Loss=0.035 Time=0.112
# File started at 14:49:30, now at 16:51:43.
# 3815 3 Loss=0.035 Time=0.144
# File started at 14:49:30, now at 16:51:43.
# 3815 4 Loss=0.035 Time=0.138
# File started at 14:49:30, now at 16:51:43.
# 3815 5 Loss=0.034 Time=0.143
# File started at 14:49:30, now at 16:51:43.
# 3815 6 Loss=0.034 Time=0.150
# File started at 14:49:30, now at 16:51:43.
# 3815 7 Loss=0.034 Time=0.111
# File started at 14:49:30, now at 16:51:43.
# 3815 8 Loss=0.031 Time=0.110
# File started at 14:49:30, now at 16:51:43.
# 3815 9 Loss=0.035 Time=0.133
# File started at 14:49:30, now at 16:51:43.
# 3815 10 Loss=0.034 Time=0.111
# File started at 14:49:30, now at 16:51:44.
# 3816 1 Loss=0.034 Time=0.117
# File started at 14:49:30, now at 16:51:44.
# 3816 2 Loss=0.034 Time=0.140
# File started at 14:49:30, now at 16:51:44.
# 3816 3 Loss=0.034 Time=0.144
# File started at 14:49:30, now at 16:51:45.
# 3816 4 Loss=0.034 Time=0.146
# File started at 14:49:30, now at 16:51:45.
# 3816 5 Loss=0.034 Time=0.147
# File started at 14:49:30, now at 16:51:45.
# 3816 6 Loss=0.033 Time=0.142
# ...
# 3978 9 Loss=0.037 Time=0.143
# File started at 14:49:30, now at 16:57:09.
# 3978 10 Loss=0.036 Time=0.118
# File started at 14:49:30, now at 16:57:09.
# 3979 1 Loss=0.034 Time=0.145
# File started at 14:49:30, now at 16:57:10.
# 3979 2 Loss=0.031 Time=0.156
# File started at 14:49:30, now at 16:57:10.
# 3979 3 Loss=0.031 Time=0.127
# File started at 14:49:30, now at 16:57:10.
# 3979 4 Loss=0.030 Time=0.119
# File started at 14:49:30, now at 16:57:10.
# 3979 5 Loss=0.032 Time=0.119
# File started at 14:49:30, now at 16:57:10.
# 3979 6 Loss=0.032 Time=0.129
# File started at 14:49:30, now at 16:57:10.
# 3979 7 Loss=0.032 Time=0.127
# File started at 14:49:30, now at 16:57:10.
# 3979 8 Loss=0.032 Time=0.166
# File started at 14:49:30, now at 16:57:11.
# 3979 9 Loss=0.031 Time=0.114
# File started at 14:49:30, now at 16:57:11.
# 3979 10 Loss=0.031 Time=0.130
# File started at 14:49:30, now at 16:57:12.
# 3980 1 Loss=0.033 Time=0.168
# File started at 14:49:30, now at 16:57:12.
# 3980 2 Loss=0.033 Time=0.118
# File started at 14:49:30, now at 16:57:12.
# 3980 3 Loss=0.030 Time=0.116
# File started at 14:49:30, now at 16:57:12.
# 3980 4 Loss=0.030 Time=0.171
# File started at 14:49:30, now at 16:57:12.
# 3980 5 Loss=0.030 Time=0.187
# File started at 14:49:30, now at 16:57:12.
# 3980 6 Loss=0.033 Time=0.174
# File started at 14:49:30, now at 16:57:13.
# 3980 7 Loss=0.033 Time=0.129
# File started at 14:49:30, now at 16:57:13.
# 3980 8 Loss=0.033 Time=0.115
# File started at 14:49:30, now at 16:57:13.
# 3980 9 Loss=0.033 Time=0.116
# File started at 14:49:30, now at 16:57:13.
# 3980 10 Loss=0.033 Time=0.123
# File started at 14:49:30, now at 16:57:14.
# 3981 1 Loss=0.032 Time=0.109
# File started at 14:49:30, now at 16:57:14.
# 3981 2 Loss=0.033 Time=0.140
# File started at 14:49:30, now at 16:57:14.
# 3981 3 Loss=0.034 Time=0.119
# File started at 14:49:30, now at 16:57:14.
# 3981 4 Loss=0.031 Time=0.112
# File started at 14:49:30, now at 16:57:14.
# 3981 5 Loss=0.031 Time=0.145
# File started at 14:49:30, now at 16:57:14.
# 3981 6 Loss=0.031 Time=0.117
# File started at 14:49:30, now at 16:57:14.
# 3981 7 Loss=0.031 Time=0.111
# File started at 14:49:30, now at 16:57:14.
# 3981 8 Loss=0.031 Time=0.141
# File started at 14:49:30, now at 16:57:15.
# 3981 9 Loss=0.031 Time=0.111
# File started at 14:49:30, now at 16:57:15.
# 3981 10 Loss=0.031 Time=0.110
# File started at 14:49:30, now at 16:57:15.
# 3982 1 Loss=0.031 Time=0.115
# File started at 14:49:30, now at 16:57:16.
# 3982 2 Loss=0.030 Time=0.111
# File started at 14:49:30, now at 16:57:16.
# 3982 3 Loss=0.030 Time=0.143
# File started at 14:49:30, now at 16:57:16.
# 3982 4 Loss=0.031 Time=0.109
# File started at 14:49:30, now at 16:57:16.
# 3982 5 Loss=0.032 Time=0.141
# File started at 14:49:30, now at 16:57:16.
# 3982 6 Loss=0.032 Time=0.152
# File started at 14:49:30, now at 16:57:16.
# 3982 7 Loss=0.031 Time=0.138
# File started at 14:49:30, now at 16:57:16.
# 3982 8 Loss=0.032 Time=0.148
# File started at 14:49:30, now at 16:57:17.
# 3982 9 Loss=0.031 Time=0.141
# File started at 14:49:30, now at 16:57:17.
# 3982 10 Loss=0.031 Time=0.144
# File started at 14:49:30, now at 16:57:17.
# 3983 1 Loss=0.034 Time=0.144
# File started at 14:49:30, now at 16:57:18.
# 3983 2 Loss=0.035 Time=0.145
# File started at 14:49:30, now at 16:57:18.
# 3983 3 Loss=0.035 Time=0.118
# File started at 14:49:30, now at 16:57:18.
# 3983 4 Loss=0.035 Time=0.110
# File started at 14:49:30, now at 16:57:18.
# 3983 5 Loss=0.035 Time=0.143
# File started at 14:49:30, now at 16:57:18.
# 3983 6 Loss=0.035 Time=0.117
# File started at 14:49:30, now at 16:57:18.
# 3983 7 Loss=0.034 Time=0.117
# File started at 14:49:30, now at 16:57:18.
# 3983 8 Loss=0.035 Time=0.142
# File started at 14:49:30, now at 16:57:18.
# 3983 9 Loss=0.034 Time=0.141
# File started at 14:49:30, now at 16:57:19.
# 3983 10 Loss=0.034 Time=0.155
# File started at 14:49:30, now at 16:57:19.
# 3984 1 Loss=0.034 Time=0.108
# File started at 14:49:30, now at 16:57:19.
# 3984 2 Loss=0.034 Time=0.154
# File started at 14:49:30, now at 16:57:20.
# 3984 3 Loss=0.035 Time=0.110
# File started at 14:49:30, now at 16:57:20.
# 3984 4 Loss=0.035 Time=0.145
# File started at 14:49:30, now at 16:57:20.
# 3984 5 Loss=0.035 Time=0.146
# File started at 14:49:30, now at 16:57:20.
# 3984 6 Loss=0.036 Time=0.118
# File started at 14:49:30, now at 16:57:20.
# 3984 7 Loss=0.036 Time=0.116
# File started at 14:49:30, now at 16:57:20.
# 3984 8 Loss=0.036 Time=0.111
# File started at 14:49:30, now at 16:57:20.
# 3984 9 Loss=0.035 Time=0.117
# File started at 14:49:30, now at 16:57:20.
# 3984 10 Loss=0.032 Time=0.110
# File started at 14:49:30, now at 16:57:21.
# 3985 1 Loss=0.033 Time=0.140
# File started at 14:49:30, now at 16:57:21.
# 3985 2 Loss=0.033 Time=0.117
# File started at 14:49:30, now at 16:57:22.
# 3985 3 Loss=0.032 Time=0.142
# File started at 14:49:30, now at 16:57:22.
# 3985 4 Loss=0.032 Time=0.118
# File started at 14:49:30, now at 16:57:22.
# 3985 5 Loss=0.032 Time=0.148
# File started at 14:49:30, now at 16:57:22.
# 3985 6 Loss=0.032 Time=0.149
# File started at 14:49:30, now at 16:57:22.
# 3985 7 Loss=0.034 Time=0.118
# File started at 14:49:30, now at 16:57:22.
# 3985 8 Loss=0.033 Time=0.118
# File started at 14:49:30, now at 16:57:22.
# 3985 9 Loss=0.031 Time=0.109
# File started at 14:49:30, now at 16:57:22.
# 3985 10 Loss=0.031 Time=0.149
# File started at 14:49:30, now at 16:57:23.
# 3986 1 Loss=0.031 Time=0.115
# File started at 14:49:30, now at 16:57:23.
# 3986 2 Loss=0.031 Time=0.116
# File started at 14:49:30, now at 16:57:24.
# 3986 3 Loss=0.030 Time=0.132
# File started at 14:49:30, now at 16:57:24.
# 3986 4 Loss=0.030 Time=0.130
# File started at 14:49:30, now at 16:57:24.
# 3986 5 Loss=0.030 Time=0.130
# File started at 14:49:30, now at 16:57:24.
# 3986 6 Loss=0.030 Time=0.182
# File started at 14:49:30, now at 16:57:24.
# 3986 7 Loss=0.032 Time=0.116
# File started at 14:49:30, now at 16:57:24.
# 3986 8 Loss=0.033 Time=0.175
# File started at 14:49:30, now at 16:57:24.
# 3986 9 Loss=0.033 Time=0.134
# File started at 14:49:30, now at 16:57:25.
# 3986 10 Loss=0.033 Time=0.116
# File started at 14:49:30, now at 16:57:25.
# 3987 1 Loss=0.032 Time=0.120
# File started at 14:49:30, now at 16:57:26.
# 3987 2 Loss=0.032 Time=0.174
# File started at 14:49:30, now at 16:57:26.
# 3987 3 Loss=0.032 Time=0.179
# File started at 14:49:30, now at 16:57:26.
# 3987 4 Loss=0.033 Time=0.175
# File started at 14:49:30, now at 16:57:26.
# 3987 5 Loss=0.033 Time=0.135
# File started at 14:49:30, now at 16:57:26.
# 3987 6 Loss=0.033 Time=0.124
# File started at 14:49:30, now at 16:57:26.
# 3987 7 Loss=0.034 Time=0.116
# File started at 14:49:30, now at 16:57:26.
# 3987 8 Loss=0.034 Time=0.110
# File started at 14:49:30, now at 16:57:27.
# 3987 9 Loss=0.032 Time=0.147
# File started at 14:49:30, now at 16:57:27.
# 3987 10 Loss=0.029 Time=0.147
# File started at 14:49:30, now at 16:57:28.
# 3988 1 Loss=0.030 Time=0.141
# File started at 14:49:30, now at 16:57:28.
# 3988 2 Loss=0.030 Time=0.146
# File started at 14:49:30, now at 16:57:28.
# 3988 3 Loss=0.031 Time=0.119
# File started at 14:49:30, now at 16:57:28.
# 3988 4 Loss=0.030 Time=0.146
# File started at 14:49:30, now at 16:57:28.
# 3988 5 Loss=0.030 Time=0.118
# File started at 14:49:30, now at 16:57:28.
# 3988 6 Loss=0.031 Time=0.111
# File started at 14:49:30, now at 16:57:28.
# 3988 7 Loss=0.032 Time=0.119
# File started at 14:49:30, now at 16:57:28.
# 3988 8 Loss=0.031 Time=0.142
# File started at 14:49:30, now at 16:57:29.
# 3988 9 Loss=0.032 Time=0.146
# File started at 14:49:30, now at 16:57:29.
# 3988 10 Loss=0.032 Time=0.141
# File started at 14:49:30, now at 16:57:29.
# 3989 1 Loss=0.030 Time=0.145
# File started at 14:49:30, now at 16:57:30.
# 3989 2 Loss=0.029 Time=0.142
# File started at 14:49:30, now at 16:57:30.
# 3989 3 Loss=0.030 Time=0.109
# File started at 14:49:30, now at 16:57:30.
# 3989 4 Loss=0.030 Time=0.117
# File started at 14:49:30, now at 16:57:30.
# 3989 5 Loss=0.030 Time=0.115
# File started at 14:49:30, now at 16:57:30.
# 3989 6 Loss=0.030 Time=0.141
# File started at 14:49:30, now at 16:57:30.
# 3989 7 Loss=0.030 Time=0.109
# File started at 14:49:30, now at 16:57:30.
# 3989 8 Loss=0.030 Time=0.115
# File started at 14:49:30, now at 16:57:30.
# 3989 9 Loss=0.030 Time=0.118
# File started at 14:49:30, now at 16:57:31.
# 3989 10 Loss=0.029 Time=0.118
# File started at 14:49:30, now at 16:57:31.
# 3990 1 Loss=0.029 Time=0.109
# File started at 14:49:30, now at 16:57:31.
# 3990 2 Loss=0.029 Time=0.147
# File started at 14:49:30, now at 16:57:32.
# 3990 3 Loss=0.029 Time=0.111
# File started at 14:49:30, now at 16:57:32.
# 3990 4 Loss=0.029 Time=0.115
# File started at 14:49:30, now at 16:57:32.
# 3990 5 Loss=0.029 Time=0.111
# File started at 14:49:30, now at 16:57:32.
# 3990 6 Loss=0.030 Time=0.144
# File started at 14:49:30, now at 16:57:32.
# 3990 7 Loss=0.030 Time=0.144
# File started at 14:49:30, now at 16:57:32.
# 3990 8 Loss=0.031 Time=0.145
# File started at 14:49:30, now at 16:57:32.
# 3990 9 Loss=0.031 Time=0.146
# File started at 14:49:30, now at 16:57:33.
# 3990 10 Loss=0.031 Time=0.142
# File started at 14:49:30, now at 16:57:33.
# 3991 1 Loss=0.030 Time=0.138
# File started at 14:49:30, now at 16:57:33.
# 3991 2 Loss=0.030 Time=0.110
# File started at 14:49:30, now at 16:57:33.
# 3991 3 Loss=0.030 Time=0.114
# File started at 14:49:30, now at 16:57:34.
# 3991 4 Loss=0.030 Time=0.141
# File started at 14:49:30, now at 16:57:34.
# 3991 5 Loss=0.030 Time=0.145
# File started at 14:49:30, now at 16:57:34.
# 3991 6 Loss=0.030 Time=0.142
# File started at 14:49:30, now at 16:57:34.
# 3991 7 Loss=0.028 Time=0.111
# File started at 14:49:30, now at 16:57:34.
# 3991 8 Loss=0.027 Time=0.109
# File started at 14:49:30, now at 16:57:34.
# 3991 9 Loss=0.028 Time=0.145
# File started at 14:49:30, now at 16:57:34.
# 3991 10 Loss=0.028 Time=0.143
# File started at 14:49:30, now at 16:57:35.
# 3992 1 Loss=0.029 Time=0.117
# File started at 14:49:30, now at 16:57:35.
# 3992 2 Loss=0.029 Time=0.142
# File started at 14:49:30, now at 16:57:35.
# 3992 3 Loss=0.029 Time=0.150
# File started at 14:49:30, now at 16:57:36.
# 3992 4 Loss=0.029 Time=0.144
# File started at 14:49:30, now at 16:57:36.
# 3992 5 Loss=0.029 Time=0.140
# File started at 14:49:30, now at 16:57:36.
# 3992 6 Loss=0.028 Time=0.111
# File started at 14:49:30, now at 16:57:36.
# 3992 7 Loss=0.030 Time=0.142
# File started at 14:49:30, now at 16:57:36.
# 3992 8 Loss=0.030 Time=0.118
# File started at 14:49:30, now at 16:57:36.
# 3992 9 Loss=0.031 Time=0.116
# File started at 14:49:30, now at 16:57:36.
# 3992 10 Loss=0.031 Time=0.147
# File started at 14:49:30, now at 16:57:37.
# 3993 1 Loss=0.030 Time=0.171
# File started at 14:49:30, now at 16:57:38.
# 3993 2 Loss=0.030 Time=0.130
# File started at 14:49:30, now at 16:57:38.
# 3993 3 Loss=0.030 Time=0.170
# File started at 14:49:30, now at 16:57:38.
# 3993 4 Loss=0.031 Time=0.181
# File started at 14:49:30, now at 16:57:38.
# 3993 5 Loss=0.031 Time=0.115
# File started at 14:49:30, now at 16:57:38.
# 3993 6 Loss=0.032 Time=0.114
# File started at 14:49:30, now at 16:57:38.
# 3993 7 Loss=0.032 Time=0.121
# File started at 14:49:30, now at 16:57:38.
# 3993 8 Loss=0.031 Time=0.176
# File started at 14:49:30, now at 16:57:39.
# 3993 9 Loss=0.031 Time=0.186
# File started at 14:49:30, now at 16:57:39.
# 3993 10 Loss=0.032 Time=0.130
# File started at 14:49:30, now at 16:57:40.
# 3994 1 Loss=0.032 Time=0.121
# File started at 14:49:30, now at 16:57:40.
# 3994 2 Loss=0.032 Time=0.143
# File started at 14:49:30, now at 16:57:40.
# 3994 3 Loss=0.032 Time=0.141
# File started at 14:49:30, now at 16:57:40.
# 3994 4 Loss=0.032 Time=0.147
# File started at 14:49:30, now at 16:57:40.
# 3994 5 Loss=0.033 Time=0.143
# File started at 14:49:30, now at 16:57:40.
# 3994 6 Loss=0.034 Time=0.156
# File started at 14:49:30, now at 16:57:41.
# 3994 7 Loss=0.033 Time=0.112
# File started at 14:49:30, now at 16:57:41.
# 3994 8 Loss=0.033 Time=0.141
# File started at 14:49:30, now at 16:57:41.
# 3994 9 Loss=0.034 Time=0.142
# File started at 14:49:30, now at 16:57:41.
# 3994 10 Loss=0.033 Time=0.109
# File started at 14:49:30, now at 16:57:42.
# 3995 1 Loss=0.034 Time=0.143
# File started at 14:49:30, now at 16:57:42.
# 3995 2 Loss=0.034 Time=0.141
# File started at 14:49:30, now at 16:57:42.
# 3995 3 Loss=0.034 Time=0.146
# File started at 14:49:30, now at 16:57:42.
# 3995 4 Loss=0.034 Time=0.141
# File started at 14:49:30, now at 16:57:42.
# 3995 5 Loss=0.034 Time=0.113
# File started at 14:49:30, now at 16:57:42.
# 3995 6 Loss=0.034 Time=0.145
# File started at 14:49:30, now at 16:57:43.
# 3995 7 Loss=0.035 Time=0.110
# File started at 14:49:30, now at 16:57:43.
# 3995 8 Loss=0.034 Time=0.145
# File started at 14:49:30, now at 16:57:43.
# 3995 9 Loss=0.033 Time=0.118
# File started at 14:49:30, now at 16:57:43.
# 3995 10 Loss=0.032 Time=0.117
# File started at 14:49:30, now at 16:57:44.
# 3996 1 Loss=0.033 Time=0.115
# File started at 14:49:30, now at 16:57:44.
# 3996 2 Loss=0.033 Time=0.117
# File started at 14:49:30, now at 16:57:44.
# 3996 3 Loss=0.033 Time=0.139
# File started at 14:49:30, now at 16:57:44.
# 3996 4 Loss=0.033 Time=0.117
# File started at 14:49:30, now at 16:57:44.
# 3996 5 Loss=0.032 Time=0.144
# File started at 14:49:30, now at 16:57:44.
# 3996 6 Loss=0.033 Time=0.144
# File started at 14:49:30, now at 16:57:44.
# 3996 7 Loss=0.033 Time=0.117
# File started at 14:49:30, now at 16:57:45.
# 3996 8 Loss=0.032 Time=0.144
# File started at 14:49:30, now at 16:57:45.
# 3996 9 Loss=0.032 Time=0.116
# File started at 14:49:30, now at 16:57:45.
# 3996 10 Loss=0.031 Time=0.117
# File started at 14:49:30, now at 16:57:46.
# 3997 1 Loss=0.030 Time=0.150
# File started at 14:49:30, now at 16:57:46.
# 3997 2 Loss=0.030 Time=0.116
# File started at 14:49:30, now at 16:57:46.
# 3997 3 Loss=0.030 Time=0.142
# File started at 14:49:30, now at 16:57:46.
# 3997 4 Loss=0.030 Time=0.146
# File started at 14:49:30, now at 16:57:46.
# 3997 5 Loss=0.030 Time=0.144
# File started at 14:49:30, now at 16:57:46.
# 3997 6 Loss=0.031 Time=0.117
# File started at 14:49:30, now at 16:57:46.
# 3997 7 Loss=0.031 Time=0.146
# File started at 14:49:30, now at 16:57:46.
# 3997 8 Loss=0.031 Time=0.146
# File started at 14:49:30, now at 16:57:47.
# 3997 9 Loss=0.031 Time=0.117
# File started at 14:49:30, now at 16:57:47.
# 3997 10 Loss=0.031 Time=0.117
# File started at 14:49:30, now at 16:57:48.
# 3998 1 Loss=0.031 Time=0.110
# File started at 14:49:30, now at 16:57:48.
# 3998 2 Loss=0.031 Time=0.110
# File started at 14:49:30, now at 16:57:48.
# 3998 3 Loss=0.030 Time=0.112
# File started at 14:49:30, now at 16:57:48.
# 3998 4 Loss=0.031 Time=0.148
# File started at 14:49:30, now at 16:57:48.
# 3998 5 Loss=0.031 Time=0.116
# File started at 14:49:30, now at 16:57:48.
# 3998 6 Loss=0.030 Time=0.110
# File started at 14:49:30, now at 16:57:48.
# 3998 7 Loss=0.029 Time=0.145
# File started at 14:49:30, now at 16:57:48.
# 3998 8 Loss=0.028 Time=0.144
# File started at 14:49:30, now at 16:57:49.
# 3998 9 Loss=0.027 Time=0.111
# File started at 14:49:30, now at 16:57:49.
# 3998 10 Loss=0.027 Time=0.107
# File started at 14:49:30, now at 16:57:49.
# 3999 1 Loss=0.027 Time=0.116
# File started at 14:49:30, now at 16:57:49.
# 3999 2 Loss=0.027 Time=0.112
# File started at 14:49:30, now at 16:57:50.
# 3999 3 Loss=0.029 Time=0.145
# File started at 14:49:30, now at 16:57:50.
# 3999 4 Loss=0.030 Time=0.114
# File started at 14:49:30, now at 16:57:50.
# 3999 5 Loss=0.030 Time=0.124
# File started at 14:49:30, now at 16:57:50.
# 3999 6 Loss=0.031 Time=0.174
# File started at 14:49:30, now at 16:57:50.
# 3999 7 Loss=0.031 Time=0.113
# File started at 14:49:30, now at 16:57:50.
# 3999 8 Loss=0.032 Time=0.167
# File started at 14:49:30, now at 16:57:50.
# 3999 9 Loss=0.032 Time=0.133
# File started at 14:49:30, now at 16:57:51.
# 3999 10 Loss=0.032 Time=0.200
# File started at 14:49:30, now at 16:57:52.
# 4000 1 Loss=0.033 Time=0.115
# File started at 14:49:30, now at 16:57:52.
# 4000 2 Loss=0.032 Time=0.178
# File started at 14:49:30, now at 16:57:52.
# 4000 3 Loss=0.033 Time=0.180
# File started at 14:49:30, now at 16:57:53.
# 4000 4 Loss=0.033 Time=0.120
# File started at 14:49:30, now at 16:57:53.
# 4000 5 Loss=0.033 Time=0.130
# File started at 14:49:30, now at 16:57:53.
# 4000 6 Loss=0.033 Time=0.162
# File started at 14:49:30, now at 16:57:53.
# 4000 7 Loss=0.033 Time=0.110
# File started at 14:49:30, now at 16:57:54.
# 4000 8 Loss=0.032 Time=0.112
# File started at 14:49:30, now at 16:57:54.
# 4000 9 Loss=0.033 Time=0.109
# File started at 14:49:30, now at 16:57:54.
# 4000 10 Loss=0.033 Time=0.141
